# %%
import os
import datetime
import numpy as np
import tensorflow as tf
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time

# %%
def maxout(inputs, num_units, axis=None):
    shape = inputs.get_shape().as_list()
    if axis is None:
        # Assume that channel is the last dimension
        axis = -1
    num_channels = shape[axis]
    if num_channels % num_units:
        raise ValueError('number of features({}) is not a multiple of num_units({})'
             .format(num_channels, num_units))
    shape[axis] = -1
    shape += [num_channels // num_units]
    outputs = tf.reduce_max(tf.reshape(inputs, shape), -1, keep_dims=False)
    return outputs

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0):
    with tf.device('/cpu:0'):
        weights = tf.Variable(
            tf.truncated_normal(
                [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
            'weights')
        biases = tf.Variable(tf.zeros([output_dim]), 'biases')
    outputs = tf.nn.dropout(nonlinearity(tf.matmul(inputs, weights) + biases), keep_prob)
    return outputs

def fully_bn_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0, train=True):
    with tf.device('/cpu:0'):
        weights = tf.Variable(
            tf.truncated_normal(
                [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
            'weights')
        z_BN = tf.matmul(inputs,weights)
        BN = tf.contrib.layers.batch_norm(z_BN, center=True, scale=True,
                                                 is_training=train)
    outputs = tf.nn.dropout(nonlinearity(BN), keep_prob)
    return outputs

def _variable_with_weight_decay(name, shape, stddev, wd):
    var = tf.get_variable(name, shape, initializer=tf.truncated_normal_initializer(stddev=stddev, dtype=tf.float32),dtype=tf.float32)
    if wd is not None:
        weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, name='weight_loss')
        tf.add_to_collection('losses', weight_decay)
    return var

# %%
random_seed = 1627522
rng = np.random.RandomState(random_seed)

train_data = CIFAR10DataProvider('train', batch_size=50, rng=rng)
valid_data = CIFAR10DataProvider('valid', batch_size=50, rng=rng)

# %%
inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
keep_prob=tf.placeholder(tf.float32)
train=tf.placeholder(bool)

with tf.variable_scope('conv1') as scope:
    inputs_new=tf.reshape(inputs,[50,3,32,32])
    inputs_new=tf.transpose(inputs_new,[0,2,3,1])
    kernel1 = _variable_with_weight_decay('conv_weights_1', shape=[3, 3, 3, 64], stddev=5e-2, wd=0.0)
    conv = tf.nn.conv2d(inputs_new, kernel1, [1, 1, 1, 1], padding='SAME')
    biases1 = tf.get_variable('biases2', [64], initializer=tf.constant_initializer(0.0), dtype=tf.float32)
    pre_activation1 = tf.nn.bias_add(conv, biases1)
    conv1=maxout(pre_activation1,64)
    #conv1 = tf.nn.relu(pre_activation1, name=scope.name)
# pool1
pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                         padding='SAME', name='pool1')
# norm1
norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm1')

# conv2
with tf.variable_scope('conv2') as scope:
    kernel2 = _variable_with_weight_decay('conv_weights_2', shape=[3, 3, 64, 64], stddev=5e-2, wd=0.0)
    conv_2 = tf.nn.conv2d(norm1, kernel2, [1, 1, 1, 1], padding='SAME')
    biases2 = tf.get_variable('biases2', [64], initializer=tf.constant_initializer(0.1), dtype=tf.float32)
    pre_activation2 = tf.nn.bias_add(conv_2, biases2)
    conv2 = maxout(pre_activation2,64)
    #_activation_summary(conv2)

# norm2
norm2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm2')
# pool2
pool2 = tf.nn.max_pool(norm2, ksize=[1, 3, 3, 1],
                         strides=[1, 2, 2, 1], padding='SAME', name='pool2')

# local3
with tf.variable_scope('local3') as scope:
    # Move everything into depth so we can perform a single matrix multiply.
    reshape = tf.reshape(pool2, [50,-1])
    hidden_1 = fully_connected_layer(reshape, 4096, 1000, keep_prob=1.0)

# local4
with tf.variable_scope('local4') as scope:
    outputs = fully_connected_layer(hidden_1, 1000, train_data.num_classes, tf.identity, keep_prob=1.0)
    
with tf.name_scope('error'):
    error = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(outputs, targets))
with tf.name_scope('accuracy'):
    accuracy = tf.reduce_mean(tf.cast(
            tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
            tf.float32))

with tf.name_scope('train'):
    train_step = tf.train.MomentumOptimizer(learning_rate=0.001,momentum=0.9).minimize(error)

# %%
init = tf.global_variables_initializer()

train_data.reset()
valid_data.reset()
running_error_one = []
running_accuracy_one = []
valid_error_one = []
valid_accuracy_one = []

with tf.Session() as sess:
    sess.run(init)
    for e in range(50):
        running_error = 0.
        running_accuracy = 0.
        start_time = time.time()
        for input_batch, target_batch in train_data:
            _, batch_error, batch_acc = sess.run(
                [train_step, error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch, keep_prob:0.8, train: True})
            running_error += batch_error
            running_accuracy += batch_acc
        epoch_time = time.time() - start_time
        running_error /= train_data.num_batches
        running_accuracy /= train_data.num_batches
        
        running_error_one.append(running_error)
        running_accuracy_one.append(running_accuracy)
        
        print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f} epoch time={3:.2f}'
              .format(e + 1, running_error, running_accuracy, epoch_time))
        
        valid_error = 0.
        valid_accuracy = 0.
        for input_batch, target_batch in valid_data:
            batch_error, batch_acc = sess.run(
                [error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch, keep_prob:1.0, train: False})
            valid_error += batch_error
            valid_accuracy += batch_acc
        valid_error /= valid_data.num_batches
        valid_accuracy /= valid_data.num_batches
            
        valid_error_one.append(valid_error)
        valid_accuracy_one.append(valid_accuracy)
            
        print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
                .format(valid_error, valid_accuracy))
# Out:
# End of epoch 01: err(train)=1.83 acc(train)=0.35 epoch time=168.42
#                  err(valid)=1.59 acc(valid)=0.43
# End of epoch 02: err(train)=1.50 acc(train)=0.48 epoch time=168.54
#                  err(valid)=1.43 acc(valid)=0.49
# End of epoch 03: err(train)=1.35 acc(train)=0.53 epoch time=166.13
#                  err(valid)=1.31 acc(valid)=0.54
# End of epoch 04: err(train)=1.23 acc(train)=0.57 epoch time=165.82
#                  err(valid)=1.21 acc(valid)=0.58
# End of epoch 05: err(train)=1.13 acc(train)=0.61 epoch time=165.52
#                  err(valid)=1.14 acc(valid)=0.60
# End of epoch 06: err(train)=1.05 acc(train)=0.63 epoch time=166.24
#                  err(valid)=1.09 acc(valid)=0.62
# End of epoch 07: err(train)=0.98 acc(train)=0.66 epoch time=165.91
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 08: err(train)=0.92 acc(train)=0.68 epoch time=166.13
#                  err(valid)=1.04 acc(valid)=0.64
# End of epoch 09: err(train)=0.86 acc(train)=0.71 epoch time=165.73
#                  err(valid)=1.03 acc(valid)=0.65
# End of epoch 10: err(train)=0.81 acc(train)=0.72 epoch time=187.18
#                  err(valid)=0.97 acc(valid)=0.66
# End of epoch 11: err(train)=0.76 acc(train)=0.74 epoch time=166.07
#                  err(valid)=0.95 acc(valid)=0.68
# End of epoch 12: err(train)=0.71 acc(train)=0.76 epoch time=169.98
#                  err(valid)=0.94 acc(valid)=0.68
# End of epoch 13: err(train)=0.66 acc(train)=0.78 epoch time=167.78
#                  err(valid)=0.94 acc(valid)=0.68
# End of epoch 14: err(train)=0.62 acc(train)=0.79 epoch time=168.99
#                  err(valid)=0.93 acc(valid)=0.69
# End of epoch 15: err(train)=0.57 acc(train)=0.81 epoch time=167.37
#                  err(valid)=0.94 acc(valid)=0.69
# End of epoch 16: err(train)=0.53 acc(train)=0.82 epoch time=167.58
#                  err(valid)=0.97 acc(valid)=0.69
# End of epoch 17: err(train)=0.49 acc(train)=0.84 epoch time=168.13
#                  err(valid)=0.95 acc(valid)=0.70
# End of epoch 18: err(train)=0.44 acc(train)=0.85 epoch time=170.41
#                  err(valid)=0.96 acc(valid)=0.70
# End of epoch 19: err(train)=0.40 acc(train)=0.87 epoch time=167.80
#                  err(valid)=0.97 acc(valid)=0.70
# End of epoch 20: err(train)=0.37 acc(train)=0.88 epoch time=167.84
#                  err(valid)=0.99 acc(valid)=0.70
# End of epoch 21: err(train)=0.33 acc(train)=0.89 epoch time=167.56
#                  err(valid)=1.06 acc(valid)=0.69
# End of epoch 22: err(train)=0.29 acc(train)=0.91 epoch time=168.48
#                  err(valid)=1.06 acc(valid)=0.70
# End of epoch 23: err(train)=0.26 acc(train)=0.92 epoch time=170.03
#                  err(valid)=1.06 acc(valid)=0.70
# End of epoch 24: err(train)=0.22 acc(train)=0.93 epoch time=169.45
#                  err(valid)=1.12 acc(valid)=0.69
# End of epoch 25: err(train)=0.20 acc(train)=0.94 epoch time=177.35
#                  err(valid)=1.15 acc(valid)=0.70
# End of epoch 26: err(train)=0.17 acc(train)=0.95 epoch time=167.45
#                  err(valid)=1.16 acc(valid)=0.70
# End of epoch 27: err(train)=0.15 acc(train)=0.96 epoch time=168.97
#                  err(valid)=1.17 acc(valid)=0.70
# End of epoch 28: err(train)=0.13 acc(train)=0.97 epoch time=168.57
#                  err(valid)=1.21 acc(valid)=0.70
# End of epoch 29: err(train)=0.10 acc(train)=0.98 epoch time=169.71
#                  err(valid)=1.29 acc(valid)=0.69
# End of epoch 30: err(train)=0.08 acc(train)=0.98 epoch time=167.75
#                  err(valid)=1.27 acc(valid)=0.70
# End of epoch 31: err(train)=0.07 acc(train)=0.99 epoch time=167.70
#                  err(valid)=1.37 acc(valid)=0.69
# End of epoch 32: err(train)=0.06 acc(train)=0.99 epoch time=170.95
#                  err(valid)=1.37 acc(valid)=0.71
# End of epoch 33: err(train)=0.04 acc(train)=0.99 epoch time=169.02
#                  err(valid)=1.34 acc(valid)=0.71
# End of epoch 34: err(train)=0.04 acc(train)=0.99 epoch time=169.57
#                  err(valid)=1.38 acc(valid)=0.71
# End of epoch 35: err(train)=0.03 acc(train)=1.00 epoch time=173.67
#                  err(valid)=1.39 acc(valid)=0.71
# End of epoch 36: err(train)=0.02 acc(train)=1.00 epoch time=167.56
#                  err(valid)=1.41 acc(valid)=0.71
# End of epoch 37: err(train)=0.02 acc(train)=1.00 epoch time=168.04
#                  err(valid)=1.43 acc(valid)=0.71
# End of epoch 38: err(train)=0.02 acc(train)=1.00 epoch time=173.56
#                  err(valid)=1.44 acc(valid)=0.71
# End of epoch 39: err(train)=0.01 acc(train)=1.00 epoch time=172.45
#                  err(valid)=1.47 acc(valid)=0.71
# End of epoch 40: err(train)=0.02 acc(train)=1.00 epoch time=172.29
#                  err(valid)=1.49 acc(valid)=0.71
# End of epoch 41: err(train)=0.01 acc(train)=1.00 epoch time=168.89
#                  err(valid)=1.49 acc(valid)=0.71
# End of epoch 42: err(train)=0.01 acc(train)=1.00 epoch time=168.94
#                  err(valid)=1.52 acc(valid)=0.71
# End of epoch 43: err(train)=0.01 acc(train)=1.00 epoch time=174.14
#                  err(valid)=1.64 acc(valid)=0.71
# End of epoch 44: err(train)=0.01 acc(train)=1.00 epoch time=168.90
#                  err(valid)=1.56 acc(valid)=0.71
# End of epoch 45: err(train)=0.01 acc(train)=1.00 epoch time=167.78
#                  err(valid)=1.56 acc(valid)=0.71
# End of epoch 46: err(train)=0.01 acc(train)=1.00 epoch time=168.28
#                  err(valid)=1.61 acc(valid)=0.71
# End of epoch 47: err(train)=0.01 acc(train)=1.00 epoch time=168.15
#                  err(valid)=1.57 acc(valid)=0.71
# End of epoch 48: err(train)=0.01 acc(train)=1.00 epoch time=169.05
#                  err(valid)=1.72 acc(valid)=0.70
# End of epoch 49: err(train)=0.01 acc(train)=1.00 epoch time=167.89
#                  err(valid)=1.62 acc(valid)=0.71
# End of epoch 50: err(train)=0.01 acc(train)=1.00 epoch time=168.89
#                  err(valid)=1.61 acc(valid)=0.71

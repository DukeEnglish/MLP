# %%
import os
import datetime
import numpy as np
import tensorflow as tf
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
import time

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0):
    with tf.device('/cpu:0'):
        weights = tf.Variable(
            tf.truncated_normal(
                [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
            'weights')
        biases = tf.Variable(tf.zeros([output_dim]), 'biases')
    outputs = tf.nn.dropout(nonlinearity(tf.matmul(inputs, weights) + biases), keep_prob)
    return outputs

def fully_bn_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0, train=True):
    with tf.device('/cpu:0'):
        weights = tf.Variable(
            tf.truncated_normal(
                [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
            'weights')
        z_BN = tf.matmul(inputs,weights)
        BN = tf.contrib.layers.batch_norm(z_BN, center=True, scale=True,
                                                 is_training=train)
    outputs = tf.nn.dropout(nonlinearity(BN), keep_prob)
    return outputs

def _variable_with_weight_decay(name, shape, stddev, wd):
    var = tf.get_variable(name, shape, initializer=tf.truncated_normal_initializer(stddev=stddev, dtype=tf.float32),dtype=tf.float32)
    if wd is not None:
        weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, name='weight_loss')
        tf.add_to_collection('losses', weight_decay)
    return var

# %%
   
def conv_bn_layer1(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0,train=True):
    kernel = _variable_with_weight_decay('weights1',
                                         shape=[5, 5, 3, 64],
                                         stddev=5e-2,
                                         wd=0.0001)
    reshape = tf.reshape(inputs, [50,32,32,3])
    conv = tf.nn.conv2d(reshape, kernel, [1, 1, 1, 1], padding='SAME')
    BN2 = tf.contrib.layers.batch_norm(conv, center=True, scale=True,
                                                 is_training=train)
    outputs = tf.nn.dropout(nonlinearity(BN), keep_prob)
    return outputs

def conv_bn_layer2(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, dropout = True, keep_prob=1.0,train=True):
    kernel = _variable_with_weight_decay('weights1',
                                         shape=[5, 5, 3, 64],
                                         stddev=5e-2,
                                         wd=0.0001)
    reshape = tf.reshape(inputs, [50,32,32,3])
    conv = tf.nn.conv2d(reshape, kernel, [1, 1, 1, 1], padding='SAME')
    BN2 = tf.contrib.layers.batch_norm(conv, center=True, scale=True,
                                                 is_training=train)
    outputs = tf.nn.dropout(nonlinearity(BN), keep_prob)
    return outputs

# %%
random_seed = 1627522
rng = np.random.RandomState(random_seed)

train_data = CIFAR10DataProvider('train', batch_size=50, rng=rng)
valid_data = CIFAR10DataProvider('valid', batch_size=50, rng=rng)

# %%
inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
keep_prob=tf.placeholder(tf.float32)
train=tf.placeholder(bool)

with tf.variable_scope('conv1') as scope:
    inputs_new=tf.reshape(inputs,[50,3,32,32])
    inputs_new=tf.transpose(inputs_new,[0,2,3,1])
    kernel1 = _variable_with_weight_decay('conv_weights_1', shape=[3, 3, 3, 64], stddev=5e-2, wd=0.0)
    conv = tf.nn.conv2d(inputs_new, kernel1, [1, 1, 1, 1], padding='SAME')
    biases1 = tf.get_variable('biases2', [64], initializer=tf.constant_initializer(0.0), dtype=tf.float32)
    pre_activation1 = tf.nn.bias_add(conv, biases1)
    conv1 = tf.nn.relu(pre_activation1, name=scope.name)

# pool1
pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                         padding='SAME', name='pool1')
# norm1
norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm1')

# conv2
with tf.variable_scope('conv2') as scope:
    kernel2 = _variable_with_weight_decay('conv_weights_2', shape=[3, 3, 64, 64], stddev=5e-2, wd=0.0)
    conv_2 = tf.nn.conv2d(norm1, kernel2, [1, 1, 1, 1], padding='SAME')
    biases2 = tf.get_variable('biases2', [64], initializer=tf.constant_initializer(0.1), dtype=tf.float32)
    pre_activation2 = tf.nn.bias_add(conv_2, biases2)
    conv2 = tf.nn.relu(pre_activation2, name=scope.name)
    #_activation_summary(conv2)

# norm2
norm2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm2')
# pool2
pool2 = tf.nn.max_pool(norm2, ksize=[1, 3, 3, 1],
                         strides=[1, 2, 2, 1], padding='SAME', name='pool2')

# local3
with tf.variable_scope('local3') as scope:
    hidden_1=tf.nn.avg_pool(norm2, ksize=[1, 16, 16, 1],
                         strides=[1, 1, 1, 1], padding='VALID', name='pool3')
    # Move everything into depth so we can perform a single matrix multiply.
    
    #hidden_1 = fully_connected_layer(reshape, 4096, 1000, keep_prob=1.0)

# local4
with tf.variable_scope('local4') as scope:
    reshape = tf.reshape(hidden_1, [50,-1])
    outputs=fully_connected_layer(reshape, 64, train_data.num_classes, tf.identity, keep_prob=1.0)
    
with tf.name_scope('error'):
    error = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=outputs, labels=targets))
with tf.name_scope('accuracy'):
    accuracy = tf.reduce_mean(tf.cast(
            tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
            tf.float32))

with tf.name_scope('train'):
    train_step = tf.train.MomentumOptimizer(learning_rate=0.001,momentum=0.9).minimize(error)

# %%
init = tf.global_variables_initializer()


train_data.reset()
valid_data.reset()
running_error_one = []
running_accuracy_one = []
valid_error_one = []
valid_accuracy_one = []

with tf.Session() as sess:
    sess.run(init)
    for e in range(200):
        running_error = 0.
        running_accuracy = 0.
        start_time = time.time()
        for input_batch, target_batch in train_data:
            _, batch_error, batch_acc = sess.run(
                [train_step, error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch, keep_prob:1.0, train: True})
            running_error += batch_error
            running_accuracy += batch_acc
        epoch_time = time.time() - start_time
        running_error /= train_data.num_batches
        running_accuracy /= train_data.num_batches
        
        running_error_one.append(running_error)
        running_accuracy_one.append(running_accuracy)
        
        print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f} epoch time={3:.2f}'
              .format(e + 1, running_error, running_accuracy, epoch_time))
        
        valid_error = 0.
        valid_accuracy = 0.
        for input_batch, target_batch in valid_data:
            batch_error, batch_acc = sess.run(
                [error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch, keep_prob:1.0, train: False})
            valid_error += batch_error
            valid_accuracy += batch_acc
        valid_error /= valid_data.num_batches
        valid_accuracy /= valid_data.num_batches
            
        valid_error_one.append(valid_error)
        valid_accuracy_one.append(valid_accuracy)
            
        print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
                .format(valid_error, valid_accuracy))
# Out:
# End of epoch 01: err(train)=2.28 acc(train)=0.13 epoch time=23.87
#                  err(valid)=2.23 acc(valid)=0.17
# End of epoch 02: err(train)=2.18 acc(train)=0.18 epoch time=23.39
#                  err(valid)=2.13 acc(valid)=0.21
# End of epoch 03: err(train)=2.10 acc(train)=0.22 epoch time=23.30
#                  err(valid)=2.08 acc(valid)=0.25
# End of epoch 04: err(train)=2.06 acc(train)=0.24 epoch time=23.44
#                  err(valid)=2.04 acc(valid)=0.25
# End of epoch 05: err(train)=2.02 acc(train)=0.27 epoch time=23.98
#                  err(valid)=2.00 acc(valid)=0.27
# End of epoch 06: err(train)=1.98 acc(train)=0.29 epoch time=24.91
#                  err(valid)=1.95 acc(valid)=0.27
# End of epoch 07: err(train)=1.92 acc(train)=0.30 epoch time=23.43
#                  err(valid)=1.89 acc(valid)=0.30
# End of epoch 08: err(train)=1.87 acc(train)=0.31 epoch time=23.77
#                  err(valid)=1.84 acc(valid)=0.32
# End of epoch 09: err(train)=1.82 acc(train)=0.33 epoch time=23.46
#                  err(valid)=1.80 acc(valid)=0.33
# End of epoch 10: err(train)=1.79 acc(train)=0.33 epoch time=23.85
#                  err(valid)=1.79 acc(valid)=0.33
# End of epoch 11: err(train)=1.77 acc(train)=0.34 epoch time=24.25
#                  err(valid)=1.75 acc(valid)=0.36
# End of epoch 12: err(train)=1.75 acc(train)=0.35 epoch time=23.60
#                  err(valid)=1.73 acc(valid)=0.36
# End of epoch 13: err(train)=1.74 acc(train)=0.35 epoch time=23.61
#                  err(valid)=1.78 acc(valid)=0.34
# End of epoch 14: err(train)=1.72 acc(train)=0.36 epoch time=24.94
#                  err(valid)=1.72 acc(valid)=0.35
# End of epoch 15: err(train)=1.72 acc(train)=0.36 epoch time=23.55
#                  err(valid)=1.70 acc(valid)=0.37
# End of epoch 16: err(train)=1.71 acc(train)=0.36 epoch time=24.36
#                  err(valid)=1.69 acc(valid)=0.37
# End of epoch 17: err(train)=1.70 acc(train)=0.37 epoch time=23.77
#                  err(valid)=1.70 acc(valid)=0.37
# End of epoch 18: err(train)=1.69 acc(train)=0.37 epoch time=24.14
#                  err(valid)=1.68 acc(valid)=0.38
# End of epoch 19: err(train)=1.68 acc(train)=0.37 epoch time=24.35
#                  err(valid)=1.69 acc(valid)=0.38
# End of epoch 20: err(train)=1.68 acc(train)=0.38 epoch time=23.83
#                  err(valid)=1.66 acc(valid)=0.39
# End of epoch 21: err(train)=1.67 acc(train)=0.38 epoch time=23.38
#                  err(valid)=1.66 acc(valid)=0.40
# End of epoch 22: err(train)=1.66 acc(train)=0.39 epoch time=23.44
#                  err(valid)=1.67 acc(valid)=0.39
# End of epoch 23: err(train)=1.65 acc(train)=0.39 epoch time=23.41
#                  err(valid)=1.64 acc(valid)=0.40
# End of epoch 24: err(train)=1.64 acc(train)=0.40 epoch time=24.00
#                  err(valid)=1.63 acc(valid)=0.41
# End of epoch 25: err(train)=1.63 acc(train)=0.40 epoch time=24.18
#                  err(valid)=1.65 acc(valid)=0.41
# End of epoch 26: err(train)=1.63 acc(train)=0.40 epoch time=23.66
#                  err(valid)=1.61 acc(valid)=0.42
# End of epoch 27: err(train)=1.62 acc(train)=0.41 epoch time=23.43
#                  err(valid)=1.60 acc(valid)=0.42
# End of epoch 28: err(train)=1.61 acc(train)=0.41 epoch time=23.62
#                  err(valid)=1.62 acc(valid)=0.42
# End of epoch 29: err(train)=1.60 acc(train)=0.42 epoch time=23.45
#                  err(valid)=1.59 acc(valid)=0.43
# End of epoch 30: err(train)=1.59 acc(train)=0.42 epoch time=23.45
#                  err(valid)=1.57 acc(valid)=0.43
# End of epoch 31: err(train)=1.58 acc(train)=0.42 epoch time=23.59
#                  err(valid)=1.56 acc(valid)=0.43
# End of epoch 32: err(train)=1.57 acc(train)=0.43 epoch time=23.50
#                  err(valid)=1.56 acc(valid)=0.43
# End of epoch 33: err(train)=1.56 acc(train)=0.43 epoch time=23.52
#                  err(valid)=1.56 acc(valid)=0.44
# End of epoch 34: err(train)=1.55 acc(train)=0.44 epoch time=23.63
#                  err(valid)=1.54 acc(valid)=0.45
# End of epoch 35: err(train)=1.55 acc(train)=0.44 epoch time=24.22
#                  err(valid)=1.55 acc(valid)=0.44
# End of epoch 36: err(train)=1.54 acc(train)=0.44 epoch time=24.19
#                  err(valid)=1.52 acc(valid)=0.45
# End of epoch 37: err(train)=1.53 acc(train)=0.44 epoch time=23.48
#                  err(valid)=1.53 acc(valid)=0.44
# End of epoch 38: err(train)=1.52 acc(train)=0.45 epoch time=23.37
#                  err(valid)=1.53 acc(valid)=0.44
# End of epoch 39: err(train)=1.52 acc(train)=0.45 epoch time=23.36
#                  err(valid)=1.51 acc(valid)=0.45
# End of epoch 40: err(train)=1.51 acc(train)=0.46 epoch time=23.34
#                  err(valid)=1.50 acc(valid)=0.45
# End of epoch 41: err(train)=1.50 acc(train)=0.46 epoch time=23.61
#                  err(valid)=1.47 acc(valid)=0.47
# End of epoch 42: err(train)=1.49 acc(train)=0.46 epoch time=23.51
#                  err(valid)=1.49 acc(valid)=0.47
# End of epoch 43: err(train)=1.48 acc(train)=0.46 epoch time=24.14
#                  err(valid)=1.48 acc(valid)=0.46
# End of epoch 44: err(train)=1.48 acc(train)=0.47 epoch time=24.20
#                  err(valid)=1.45 acc(valid)=0.48
# End of epoch 45: err(train)=1.47 acc(train)=0.47 epoch time=24.05
#                  err(valid)=1.45 acc(valid)=0.48
# End of epoch 46: err(train)=1.46 acc(train)=0.47 epoch time=24.23
#                  err(valid)=1.52 acc(valid)=0.45
# End of epoch 47: err(train)=1.46 acc(train)=0.48 epoch time=23.55
#                  err(valid)=1.45 acc(valid)=0.48
# End of epoch 48: err(train)=1.45 acc(train)=0.48 epoch time=23.73
#                  err(valid)=1.43 acc(valid)=0.48
# End of epoch 49: err(train)=1.44 acc(train)=0.48 epoch time=23.51
#                  err(valid)=1.43 acc(valid)=0.49
# End of epoch 50: err(train)=1.44 acc(train)=0.49 epoch time=23.54
#                  err(valid)=1.45 acc(valid)=0.48
# End of epoch 51: err(train)=1.43 acc(train)=0.49 epoch time=23.59
#                  err(valid)=1.50 acc(valid)=0.46
# End of epoch 52: err(train)=1.43 acc(train)=0.49 epoch time=23.63
#                  err(valid)=1.42 acc(valid)=0.50
# End of epoch 53: err(train)=1.42 acc(train)=0.49 epoch time=23.44
#                  err(valid)=1.41 acc(valid)=0.49
# End of epoch 54: err(train)=1.41 acc(train)=0.50 epoch time=23.43
#                  err(valid)=1.39 acc(valid)=0.51
# End of epoch 55: err(train)=1.41 acc(train)=0.50 epoch time=23.35
#                  err(valid)=1.38 acc(valid)=0.51
# End of epoch 56: err(train)=1.40 acc(train)=0.50 epoch time=23.45
#                  err(valid)=1.39 acc(valid)=0.51
# End of epoch 57: err(train)=1.39 acc(train)=0.50 epoch time=21.41
#                  err(valid)=1.45 acc(valid)=0.49
# End of epoch 58: err(train)=1.39 acc(train)=0.50 epoch time=17.52
#                  err(valid)=1.37 acc(valid)=0.51
# End of epoch 59: err(train)=1.38 acc(train)=0.51 epoch time=17.72
#                  err(valid)=1.37 acc(valid)=0.51
# End of epoch 60: err(train)=1.38 acc(train)=0.51 epoch time=17.63
#                  err(valid)=1.39 acc(valid)=0.49
# End of epoch 61: err(train)=1.37 acc(train)=0.51 epoch time=17.66
#                  err(valid)=1.36 acc(valid)=0.52
# End of epoch 62: err(train)=1.37 acc(train)=0.51 epoch time=17.51
#                  err(valid)=1.38 acc(valid)=0.51
# End of epoch 63: err(train)=1.37 acc(train)=0.51 epoch time=17.98
#                  err(valid)=1.39 acc(valid)=0.50
# End of epoch 64: err(train)=1.36 acc(train)=0.52 epoch time=17.71
#                  err(valid)=1.34 acc(valid)=0.53
# End of epoch 65: err(train)=1.36 acc(train)=0.52 epoch time=17.73
#                  err(valid)=1.35 acc(valid)=0.52
# End of epoch 66: err(train)=1.35 acc(train)=0.52 epoch time=17.74
#                  err(valid)=1.34 acc(valid)=0.52
# End of epoch 67: err(train)=1.35 acc(train)=0.52 epoch time=17.74
#                  err(valid)=1.34 acc(valid)=0.53
# End of epoch 68: err(train)=1.34 acc(train)=0.52 epoch time=17.74
#                  err(valid)=1.32 acc(valid)=0.54
# End of epoch 69: err(train)=1.34 acc(train)=0.52 epoch time=17.70
#                  err(valid)=1.33 acc(valid)=0.53
# End of epoch 70: err(train)=1.33 acc(train)=0.52 epoch time=17.72
#                  err(valid)=1.32 acc(valid)=0.52
# End of epoch 71: err(train)=1.33 acc(train)=0.53 epoch time=17.70
#                  err(valid)=1.34 acc(valid)=0.52
# End of epoch 72: err(train)=1.33 acc(train)=0.53 epoch time=17.72
#                  err(valid)=1.34 acc(valid)=0.52
# End of epoch 73: err(train)=1.33 acc(train)=0.53 epoch time=17.71
#                  err(valid)=1.37 acc(valid)=0.51
# End of epoch 74: err(train)=1.32 acc(train)=0.53 epoch time=17.72
#                  err(valid)=1.30 acc(valid)=0.54
# End of epoch 75: err(train)=1.32 acc(train)=0.53 epoch time=17.89
#                  err(valid)=1.29 acc(valid)=0.54
# End of epoch 76: err(train)=1.31 acc(train)=0.53 epoch time=17.70
#                  err(valid)=1.29 acc(valid)=0.54
# End of epoch 77: err(train)=1.31 acc(train)=0.53 epoch time=17.71
#                  err(valid)=1.33 acc(valid)=0.53
# End of epoch 78: err(train)=1.31 acc(train)=0.53 epoch time=17.71
#                  err(valid)=1.29 acc(valid)=0.54
# End of epoch 79: err(train)=1.30 acc(train)=0.54 epoch time=17.70
#                  err(valid)=1.29 acc(valid)=0.54
# End of epoch 80: err(train)=1.30 acc(train)=0.54 epoch time=17.74
#                  err(valid)=1.31 acc(valid)=0.53
# End of epoch 81: err(train)=1.30 acc(train)=0.54 epoch time=17.72
#                  err(valid)=1.32 acc(valid)=0.52
# End of epoch 82: err(train)=1.29 acc(train)=0.54 epoch time=17.69
#                  err(valid)=1.30 acc(valid)=0.54
# End of epoch 83: err(train)=1.29 acc(train)=0.54 epoch time=17.71
#                  err(valid)=1.30 acc(valid)=0.54
# End of epoch 84: err(train)=1.29 acc(train)=0.54 epoch time=17.49
#                  err(valid)=1.27 acc(valid)=0.55
# End of epoch 85: err(train)=1.28 acc(train)=0.54 epoch time=17.17
#                  err(valid)=1.27 acc(valid)=0.55
# End of epoch 86: err(train)=1.28 acc(train)=0.55 epoch time=17.21
#                  err(valid)=1.26 acc(valid)=0.55
# End of epoch 87: err(train)=1.28 acc(train)=0.55 epoch time=17.25
#                  err(valid)=1.28 acc(valid)=0.55
# End of epoch 88: err(train)=1.27 acc(train)=0.55 epoch time=17.24
#                  err(valid)=1.29 acc(valid)=0.54
# End of epoch 89: err(train)=1.27 acc(train)=0.55 epoch time=17.23
#                  err(valid)=1.26 acc(valid)=0.55
# End of epoch 90: err(train)=1.27 acc(train)=0.55 epoch time=17.19
#                  err(valid)=1.26 acc(valid)=0.55
# End of epoch 91: err(train)=1.27 acc(train)=0.55 epoch time=17.22
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 92: err(train)=1.26 acc(train)=0.55 epoch time=17.25
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 93: err(train)=1.25 acc(train)=0.56 epoch time=17.22
#                  err(valid)=1.25 acc(valid)=0.56
# End of epoch 94: err(train)=1.26 acc(train)=0.55 epoch time=17.21
#                  err(valid)=1.26 acc(valid)=0.55
# End of epoch 95: err(train)=1.25 acc(train)=0.56 epoch time=17.27
#                  err(valid)=1.25 acc(valid)=0.55
# End of epoch 96: err(train)=1.25 acc(train)=0.56 epoch time=17.24
#                  err(valid)=1.26 acc(valid)=0.55
# End of epoch 97: err(train)=1.25 acc(train)=0.56 epoch time=17.22
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 98: err(train)=1.24 acc(train)=0.56 epoch time=17.16
#                  err(valid)=1.23 acc(valid)=0.57
# End of epoch 99: err(train)=1.24 acc(train)=0.56 epoch time=17.29
#                  err(valid)=1.23 acc(valid)=0.57
# End of epoch 100: err(train)=1.24 acc(train)=0.56 epoch time=17.22
#                  err(valid)=1.23 acc(valid)=0.57
# End of epoch 101: err(train)=1.24 acc(train)=0.56 epoch time=17.23
#                  err(valid)=1.23 acc(valid)=0.57
# End of epoch 102: err(train)=1.23 acc(train)=0.57 epoch time=17.22
#                  err(valid)=1.22 acc(valid)=0.57
# End of epoch 103: err(train)=1.23 acc(train)=0.56 epoch time=17.20
#                  err(valid)=1.22 acc(valid)=0.57
# End of epoch 104: err(train)=1.23 acc(train)=0.56 epoch time=17.28
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 105: err(train)=1.23 acc(train)=0.57 epoch time=17.30
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 106: err(train)=1.22 acc(train)=0.57 epoch time=17.28
#                  err(valid)=1.23 acc(valid)=0.56
# End of epoch 107: err(train)=1.22 acc(train)=0.57 epoch time=17.16
#                  err(valid)=1.23 acc(valid)=0.56
# End of epoch 108: err(train)=1.22 acc(train)=0.57 epoch time=17.24
#                  err(valid)=1.21 acc(valid)=0.57
# End of epoch 109: err(train)=1.21 acc(train)=0.57 epoch time=17.22
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 110: err(train)=1.21 acc(train)=0.57 epoch time=17.27
#                  err(valid)=1.25 acc(valid)=0.55
# End of epoch 111: err(train)=1.21 acc(train)=0.57 epoch time=17.20
#                  err(valid)=1.27 acc(valid)=0.55
# End of epoch 112: err(train)=1.21 acc(train)=0.57 epoch time=17.24
#                  err(valid)=1.23 acc(valid)=0.56
# End of epoch 113: err(train)=1.21 acc(train)=0.57 epoch time=17.22
#                  err(valid)=1.22 acc(valid)=0.57
# End of epoch 114: err(train)=1.20 acc(train)=0.57 epoch time=17.28
#                  err(valid)=1.22 acc(valid)=0.57
# End of epoch 115: err(train)=1.20 acc(train)=0.58 epoch time=17.30
#                  err(valid)=1.24 acc(valid)=0.56
# End of epoch 116: err(train)=1.20 acc(train)=0.58 epoch time=17.26
#                  err(valid)=1.21 acc(valid)=0.57
# End of epoch 117: err(train)=1.20 acc(train)=0.58 epoch time=17.24
#                  err(valid)=1.19 acc(valid)=0.58
# End of epoch 118: err(train)=1.20 acc(train)=0.58 epoch time=17.24
#                  err(valid)=1.20 acc(valid)=0.58
# End of epoch 119: err(train)=1.19 acc(train)=0.58 epoch time=17.18
#                  err(valid)=1.18 acc(valid)=0.59
# End of epoch 120: err(train)=1.19 acc(train)=0.58 epoch time=17.21
#                  err(valid)=1.17 acc(valid)=0.59
# End of epoch 121: err(train)=1.18 acc(train)=0.58 epoch time=17.20
#                  err(valid)=1.20 acc(valid)=0.57
# End of epoch 122: err(train)=1.18 acc(train)=0.58 epoch time=17.28
#                  err(valid)=1.17 acc(valid)=0.59
# End of epoch 123: err(train)=1.18 acc(train)=0.58 epoch time=17.27
#                  err(valid)=1.17 acc(valid)=0.59
# End of epoch 124: err(train)=1.18 acc(train)=0.58 epoch time=17.17
#                  err(valid)=1.19 acc(valid)=0.58
# End of epoch 125: err(train)=1.17 acc(train)=0.58 epoch time=17.24
#                  err(valid)=1.18 acc(valid)=0.58
# End of epoch 126: err(train)=1.17 acc(train)=0.58 epoch time=17.19
#                  err(valid)=1.18 acc(valid)=0.58
# End of epoch 127: err(train)=1.17 acc(train)=0.59 epoch time=17.34
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 128: err(train)=1.17 acc(train)=0.59 epoch time=17.25
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 129: err(train)=1.17 acc(train)=0.59 epoch time=17.20
#                  err(valid)=1.17 acc(valid)=0.59
# End of epoch 130: err(train)=1.17 acc(train)=0.59 epoch time=17.23
#                  err(valid)=1.15 acc(valid)=0.60
# End of epoch 131: err(train)=1.16 acc(train)=0.59 epoch time=17.28
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 132: err(train)=1.16 acc(train)=0.59 epoch time=17.26
#                  err(valid)=1.15 acc(valid)=0.60
# End of epoch 133: err(train)=1.16 acc(train)=0.59 epoch time=17.19
#                  err(valid)=1.15 acc(valid)=0.59
# End of epoch 134: err(train)=1.15 acc(train)=0.59 epoch time=17.20
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 135: err(train)=1.15 acc(train)=0.60 epoch time=17.25
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 136: err(train)=1.15 acc(train)=0.59 epoch time=17.23
#                  err(valid)=1.15 acc(valid)=0.59
# End of epoch 137: err(train)=1.15 acc(train)=0.59 epoch time=17.20
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 138: err(train)=1.15 acc(train)=0.60 epoch time=17.28
#                  err(valid)=1.15 acc(valid)=0.59
# End of epoch 139: err(train)=1.14 acc(train)=0.60 epoch time=17.25
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 140: err(train)=1.14 acc(train)=0.60 epoch time=17.25
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 141: err(train)=1.14 acc(train)=0.60 epoch time=17.25
#                  err(valid)=1.18 acc(valid)=0.58
# End of epoch 142: err(train)=1.14 acc(train)=0.60 epoch time=17.23
#                  err(valid)=1.14 acc(valid)=0.60
# End of epoch 143: err(train)=1.13 acc(train)=0.60 epoch time=17.22
#                  err(valid)=1.14 acc(valid)=0.60
# End of epoch 144: err(train)=1.13 acc(train)=0.60 epoch time=17.26
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 145: err(train)=1.13 acc(train)=0.60 epoch time=17.22
#                  err(valid)=1.12 acc(valid)=0.61
# End of epoch 146: err(train)=1.13 acc(train)=0.60 epoch time=17.27
#                  err(valid)=1.12 acc(valid)=0.61
# End of epoch 147: err(train)=1.13 acc(train)=0.60 epoch time=17.22
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 148: err(train)=1.12 acc(train)=0.60 epoch time=17.20
#                  err(valid)=1.16 acc(valid)=0.59
# End of epoch 149: err(train)=1.12 acc(train)=0.61 epoch time=17.33
#                  err(valid)=1.12 acc(valid)=0.61
# End of epoch 150: err(train)=1.12 acc(train)=0.61 epoch time=17.25
#                  err(valid)=1.18 acc(valid)=0.58
# End of epoch 151: err(train)=1.12 acc(train)=0.61 epoch time=17.27
#                  err(valid)=1.12 acc(valid)=0.61
# End of epoch 152: err(train)=1.12 acc(train)=0.61 epoch time=17.19
#                  err(valid)=1.15 acc(valid)=0.59
# End of epoch 153: err(train)=1.12 acc(train)=0.61 epoch time=17.20
#                  err(valid)=1.14 acc(valid)=0.60
# End of epoch 154: err(train)=1.11 acc(train)=0.61 epoch time=17.28
#                  err(valid)=1.12 acc(valid)=0.61
# End of epoch 155: err(train)=1.11 acc(train)=0.61 epoch time=17.21
#                  err(valid)=1.10 acc(valid)=0.62
# End of epoch 156: err(train)=1.11 acc(train)=0.61 epoch time=17.25
#                  err(valid)=1.11 acc(valid)=0.61
# End of epoch 157: err(train)=1.11 acc(train)=0.61 epoch time=17.23
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 158: err(train)=1.10 acc(train)=0.61 epoch time=17.25
#                  err(valid)=1.13 acc(valid)=0.60
# End of epoch 159: err(train)=1.11 acc(train)=0.61 epoch time=17.21
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 160: err(train)=1.10 acc(train)=0.61 epoch time=17.26
#                  err(valid)=1.11 acc(valid)=0.61
# End of epoch 161: err(train)=1.10 acc(train)=0.61 epoch time=17.19
#                  err(valid)=1.11 acc(valid)=0.61
# End of epoch 162: err(train)=1.10 acc(train)=0.62 epoch time=17.28
#                  err(valid)=1.10 acc(valid)=0.62
# End of epoch 163: err(train)=1.10 acc(train)=0.61 epoch time=17.25
#                  err(valid)=1.11 acc(valid)=0.61
# End of epoch 164: err(train)=1.09 acc(train)=0.61 epoch time=17.20
#                  err(valid)=1.12 acc(valid)=0.60
# End of epoch 165: err(train)=1.09 acc(train)=0.62 epoch time=17.23
#                  err(valid)=1.09 acc(valid)=0.62
# End of epoch 166: err(train)=1.09 acc(train)=0.62 epoch time=17.16
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 167: err(train)=1.09 acc(train)=0.62 epoch time=17.25
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 168: err(train)=1.09 acc(train)=0.62 epoch time=17.15
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 169: err(train)=1.09 acc(train)=0.62 epoch time=17.24
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 170: err(train)=1.09 acc(train)=0.62 epoch time=17.20
#                  err(valid)=1.09 acc(valid)=0.61
# End of epoch 171: err(train)=1.08 acc(train)=0.62 epoch time=17.18
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 172: err(train)=1.08 acc(train)=0.62 epoch time=17.26
#                  err(valid)=1.09 acc(valid)=0.62
# End of epoch 173: err(train)=1.08 acc(train)=0.62 epoch time=17.13
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 174: err(train)=1.08 acc(train)=0.62 epoch time=17.23
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 175: err(train)=1.08 acc(train)=0.62 epoch time=17.24
#                  err(valid)=1.09 acc(valid)=0.62
# End of epoch 176: err(train)=1.07 acc(train)=0.62 epoch time=17.12
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 177: err(train)=1.07 acc(train)=0.62 epoch time=17.18
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 178: err(train)=1.07 acc(train)=0.62 epoch time=17.27
#                  err(valid)=1.12 acc(valid)=0.60
# End of epoch 179: err(train)=1.07 acc(train)=0.62 epoch time=17.22
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 180: err(train)=1.07 acc(train)=0.62 epoch time=17.23
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 181: err(train)=1.07 acc(train)=0.62 epoch time=17.17
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 182: err(train)=1.07 acc(train)=0.63 epoch time=17.24
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 183: err(train)=1.06 acc(train)=0.63 epoch time=17.26
#                  err(valid)=1.10 acc(valid)=0.61
# End of epoch 184: err(train)=1.06 acc(train)=0.63 epoch time=17.25
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 185: err(train)=1.06 acc(train)=0.63 epoch time=17.17
#                  err(valid)=1.07 acc(valid)=0.62
# End of epoch 186: err(train)=1.06 acc(train)=0.63 epoch time=17.25
#                  err(valid)=1.09 acc(valid)=0.61
# End of epoch 187: err(train)=1.06 acc(train)=0.63 epoch time=17.23
#                  err(valid)=1.09 acc(valid)=0.61
# End of epoch 188: err(train)=1.06 acc(train)=0.63 epoch time=17.20
#                  err(valid)=1.08 acc(valid)=0.62
# End of epoch 189: err(train)=1.06 acc(train)=0.63 epoch time=17.15
#                  err(valid)=1.07 acc(valid)=0.62
# End of epoch 190: err(train)=1.06 acc(train)=0.63 epoch time=17.16
#                  err(valid)=1.06 acc(valid)=0.62
# End of epoch 191: err(train)=1.05 acc(train)=0.63 epoch time=17.23
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 192: err(train)=1.05 acc(train)=0.63 epoch time=17.18
#                  err(valid)=1.05 acc(valid)=0.63
# End of epoch 193: err(train)=1.05 acc(train)=0.63 epoch time=17.15
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 194: err(train)=1.05 acc(train)=0.63 epoch time=17.23
#                  err(valid)=1.05 acc(valid)=0.63
# End of epoch 195: err(train)=1.05 acc(train)=0.63 epoch time=17.19
#                  err(valid)=1.07 acc(valid)=0.62
# End of epoch 196: err(train)=1.04 acc(train)=0.63 epoch time=17.34
#                  err(valid)=1.06 acc(valid)=0.62
# End of epoch 197: err(train)=1.04 acc(train)=0.63 epoch time=17.23
#                  err(valid)=1.06 acc(valid)=0.62
# End of epoch 198: err(train)=1.04 acc(train)=0.63 epoch time=17.26
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 199: err(train)=1.04 acc(train)=0.64 epoch time=17.19
#                  err(valid)=1.06 acc(valid)=0.63
# End of epoch 200: err(train)=1.04 acc(train)=0.63 epoch time=17.16
#                  err(valid)=1.06 acc(valid)=0.62

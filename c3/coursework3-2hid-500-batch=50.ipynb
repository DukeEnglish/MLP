# %% [markdown]
# ## Example two-layer classifier models
#
# Below example code is given for creating instances of the CIFAR-10 and CIFAR-100 data provider objects and using them to train simple two-layer feedforward network models with rectified linear activations in TensorFlow. You may wish to use this code as a starting point for your own experiments.

# %%
import os
import tensorflow as tf
import numpy as np
import time
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1,different activation functions : change in defination of fully_connected_layer
# 2,different hidden layer depths: change the construction of net
# 3,different widths,: change num_hidden
# 4,different learning rate schedules,
# 5,different normalisation,
# 6,different regularisation.

# %% [markdown]
# ### CIFAR-10

# %%
train_data = CIFAR10DataProvider('train', batch_size=50)
valid_data = CIFAR10DataProvider('valid', batch_size=50)

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu):
    weights = tf.Variable(
        tf.truncated_normal(
            [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
        'weights')
    biases = tf.Variable(tf.zeros([output_dim]), 'biases')
    outputs = nonlinearity(tf.matmul(inputs, weights) + biases)
    return outputs

# %% [markdown]
# # coursework3-2hid-500-batch=50

# %%
#activations = [tf.nn.relu]
# 2 hidden
activations = [tf.nn.sigmoid,tf.nn.relu,tf.nn.tanh,tf.nn.elu]
epoch=50
running_error_=np.zeros((len(activations),epoch))
running_accuracy_ = np.zeros((len(activations),epoch))
valid_error_ = np.zeros((len(activations),epoch))
valid_accuracy_ = np.zeros((len(activations),epoch))
loop=0
## store result in 4 arrays
for activation in activations:
    print(activation.func_name+"--------------------------------------------------")
    inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
    num_hidden = 500

    with tf.name_scope('fc-layer-1'):
        hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden, nonlinearity=activation)
    with tf.name_scope('layer-2'):
        hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        outputs = fully_connected_layer(hidden_2, num_hidden, train_data.num_classes, tf.identity)
    with tf.name_scope('error'):
        error = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(outputs, targets))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(
                tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
                tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)

    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        run_sum_time = time.time()
        for e in range(epoch):
            run_start_time = time.time()
            running_error = 0.
            running_accuracy = 0.
            for input_batch, target_batch in train_data:
                _, batch_error, batch_acc = sess.run(
                    [train_step, error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                running_error += batch_error
                running_accuracy += batch_acc
            running_error /= train_data.num_batches
            running_accuracy /= train_data.num_batches
            print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f}'
                  .format(e + 1, running_error, running_accuracy))
            running_error_[loop][e]=running_error
            running_accuracy_[loop][e]=running_accuracy
            ##if (e + 1) % 5 == 0:
            valid_error = 0.
            valid_accuracy = 0.
            for input_batch, target_batch in valid_data:
                batch_error, batch_acc = sess.run(
                    [error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                valid_error += batch_error
                valid_accuracy += batch_acc
            valid_error /= valid_data.num_batches
            valid_accuracy /= valid_data.num_batches
            print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
                    .format(valid_error, valid_accuracy))
            valid_error_[loop][e]=valid_error
            valid_accuracy_[loop][e]=valid_accuracy
            run_time = time.time() - run_start_time
            print run_time
        time_epochs=time.time()-run_sum_time
        print("sum time for epochs", time_epochs)
    loop+=1
# Out:
# sigmoid--------------------------------------------------
# End of epoch 01: err(train)=1.91 acc(train)=0.31
#                  err(valid)=1.83 acc(valid)=0.34
# 13.8574240208
# End of epoch 02: err(train)=1.74 acc(train)=0.37
#                  err(valid)=1.70 acc(valid)=0.39
# 14.0019860268
# End of epoch 03: err(train)=1.67 acc(train)=0.40
#                  err(valid)=1.67 acc(valid)=0.40
# 13.7271990776
# End of epoch 04: err(train)=1.63 acc(train)=0.41
#                  err(valid)=1.65 acc(valid)=0.41
# 14.0149619579
# End of epoch 05: err(train)=1.60 acc(train)=0.42
#                  err(valid)=1.59 acc(valid)=0.42
# 14.2882778645
# End of epoch 06: err(train)=1.57 acc(train)=0.43
#                  err(valid)=1.61 acc(valid)=0.42
# 14.7081370354
# End of epoch 07: err(train)=1.56 acc(train)=0.44
#                  err(valid)=1.62 acc(valid)=0.42
# 15.4185709953
# End of epoch 08: err(train)=1.53 acc(train)=0.45
#                  err(valid)=1.65 acc(valid)=0.42
# 15.8436820507
# End of epoch 09: err(train)=1.52 acc(train)=0.45
#                  err(valid)=1.60 acc(valid)=0.43
# 15.8759009838
# End of epoch 10: err(train)=1.52 acc(train)=0.46
#                  err(valid)=1.54 acc(valid)=0.45
# 16.9686870575
# End of epoch 11: err(train)=1.50 acc(train)=0.46
#                  err(valid)=1.57 acc(valid)=0.44
# 17.8787841797
# End of epoch 12: err(train)=1.49 acc(train)=0.46
#                  err(valid)=1.58 acc(valid)=0.44
# 18.8063950539
# End of epoch 13: err(train)=1.48 acc(train)=0.47
#                  err(valid)=1.52 acc(valid)=0.46
# 19.6883621216
# End of epoch 14: err(train)=1.48 acc(train)=0.47
#                  err(valid)=1.53 acc(valid)=0.46
# 20.708286047
# End of epoch 15: err(train)=1.47 acc(train)=0.47
#                  err(valid)=1.56 acc(valid)=0.44
# 21.6703650951
# End of epoch 16: err(train)=1.45 acc(train)=0.48
#                  err(valid)=1.55 acc(valid)=0.46
# 23.2952060699
# End of epoch 17: err(train)=1.44 acc(train)=0.48
#                  err(valid)=1.56 acc(valid)=0.46
# 24.3541529179
# End of epoch 18: err(train)=1.44 acc(train)=0.48
#                  err(valid)=1.55 acc(valid)=0.45
# 25.8932011127
# End of epoch 19: err(train)=1.43 acc(train)=0.49
#                  err(valid)=1.55 acc(valid)=0.44
# 27.9820458889
# End of epoch 20: err(train)=1.42 acc(train)=0.49
#                  err(valid)=1.58 acc(valid)=0.44
# 28.1722099781
# End of epoch 21: err(train)=1.41 acc(train)=0.49
#                  err(valid)=1.56 acc(valid)=0.45
# 30.5439319611
# End of epoch 22: err(train)=1.41 acc(train)=0.50
#                  err(valid)=1.62 acc(valid)=0.43
# 31.378068924
# End of epoch 23: err(train)=1.40 acc(train)=0.50
#                  err(valid)=1.56 acc(valid)=0.45
# 33.2787868977
# End of epoch 24: err(train)=1.39 acc(train)=0.50
#                  err(valid)=1.53 acc(valid)=0.47
# 34.650562048
# End of epoch 25: err(train)=1.38 acc(train)=0.51
#                  err(valid)=1.51 acc(valid)=0.47
# 36.9947371483
# End of epoch 26: err(train)=1.37 acc(train)=0.51
#                  err(valid)=1.50 acc(valid)=0.47
# 43.9474329948
# End of epoch 27: err(train)=1.37 acc(train)=0.51
#                  err(valid)=1.55 acc(valid)=0.46
# 40.807033062
# End of epoch 28: err(train)=1.36 acc(train)=0.51
#                  err(valid)=1.52 acc(valid)=0.47
# 41.462239027
# End of epoch 29: err(train)=1.37 acc(train)=0.51
#                  err(valid)=1.52 acc(valid)=0.47
# 41.4366700649
# End of epoch 30: err(train)=1.36 acc(train)=0.52
#                  err(valid)=1.53 acc(valid)=0.47
# 43.3499279022
# End of epoch 31: err(train)=1.34 acc(train)=0.52
#                  err(valid)=1.52 acc(valid)=0.47
# 47.3899829388
# End of epoch 32: err(train)=1.34 acc(train)=0.52
#                  err(valid)=1.58 acc(valid)=0.44
# 43.9675431252
# End of epoch 33: err(train)=1.32 acc(train)=0.53
#                  err(valid)=1.58 acc(valid)=0.45
# 48.0057871342
# End of epoch 34: err(train)=1.32 acc(train)=0.53
#                  err(valid)=1.52 acc(valid)=0.47
# 49.4826879501
# End of epoch 35: err(train)=1.31 acc(train)=0.53
#                  err(valid)=1.61 acc(valid)=0.44
# 47.3838369846
# End of epoch 36: err(train)=1.30 acc(train)=0.53
#                  err(valid)=1.59 acc(valid)=0.44
# 48.3799278736
# End of epoch 37: err(train)=1.30 acc(train)=0.53
#                  err(valid)=1.53 acc(valid)=0.47
# 51.9024908543
# End of epoch 38: err(train)=1.29 acc(train)=0.54
#                  err(valid)=1.53 acc(valid)=0.47
# 48.61322999
# End of epoch 39: err(train)=1.29 acc(train)=0.54
#                  err(valid)=1.56 acc(valid)=0.47
# 52.4338190556
# End of epoch 40: err(train)=1.29 acc(train)=0.54
#                  err(valid)=1.55 acc(valid)=0.46
# 50.7875840664
# End of epoch 41: err(train)=1.29 acc(train)=0.54
#                  err(valid)=1.52 acc(valid)=0.47
# 52.5786070824
# End of epoch 42: err(train)=1.28 acc(train)=0.54
#                  err(valid)=1.54 acc(valid)=0.46
# 47.7776989937
# End of epoch 43: err(train)=1.27 acc(train)=0.54
#                  err(valid)=1.54 acc(valid)=0.47
# 48.0231218338
# End of epoch 44: err(train)=1.26 acc(train)=0.55
#                  err(valid)=1.54 acc(valid)=0.47
# 47.9401528835
# End of epoch 45: err(train)=1.26 acc(train)=0.55
#                  err(valid)=1.52 acc(valid)=0.48
# 48.2781219482
# End of epoch 46: err(train)=1.25 acc(train)=0.55
#                  err(valid)=1.55 acc(valid)=0.47
# 47.8277580738
# End of epoch 47: err(train)=1.25 acc(train)=0.55
#                  err(valid)=1.53 acc(valid)=0.47
# 48.3642630577
# End of epoch 48: err(train)=1.23 acc(train)=0.56
#                  err(valid)=1.56 acc(valid)=0.47
# 52.3700678349
# End of epoch 49: err(train)=1.24 acc(train)=0.56
#                  err(valid)=1.56 acc(valid)=0.47
# 50.5681231022
# End of epoch 50: err(train)=1.24 acc(train)=0.56
#                  err(valid)=1.55 acc(valid)=0.47
# 54.4502239227
# ('sum time for epochs', 1741.5306189060211)
# relu--------------------------------------------------
# End of epoch 01: err(train)=1.91 acc(train)=0.32
#                  err(valid)=1.73 acc(valid)=0.38
# 14.7245740891
# End of epoch 02: err(train)=1.70 acc(train)=0.39
#                  err(valid)=1.69 acc(valid)=0.40
# 22.0085508823
# End of epoch 03: err(train)=1.61 acc(train)=0.42
#                  err(valid)=1.60 acc(valid)=0.43
# 21.5962378979
# End of epoch 04: err(train)=1.56 acc(train)=0.44
#                  err(valid)=1.60 acc(valid)=0.43
# 20.2129719257
# End of epoch 05: err(train)=1.52 acc(train)=0.46
#                  err(valid)=1.56 acc(valid)=0.44
# 20.8746979237
# End of epoch 06: err(train)=1.49 acc(train)=0.47
#                  err(valid)=1.53 acc(valid)=0.46
# 20.0383710861
# End of epoch 07: err(train)=1.47 acc(train)=0.47
#                  err(valid)=1.54 acc(valid)=0.46
# 21.5660040379
# End of epoch 08: err(train)=1.44 acc(train)=0.49
#                  err(valid)=1.54 acc(valid)=0.46
# 20.7551438808
# End of epoch 09: err(train)=1.41 acc(train)=0.49
#                  err(valid)=1.50 acc(valid)=0.46
# 19.7251110077
# End of epoch 10: err(train)=1.39 acc(train)=0.50
#                  err(valid)=1.50 acc(valid)=0.47
# 22.464507103
# End of epoch 11: err(train)=1.38 acc(train)=0.51
#                  err(valid)=1.49 acc(valid)=0.47
# 19.2954409122
# End of epoch 12: err(train)=1.36 acc(train)=0.52
#                  err(valid)=1.50 acc(valid)=0.48
# 21.0173530579
# End of epoch 13: err(train)=1.34 acc(train)=0.52
#                  err(valid)=1.54 acc(valid)=0.46
# 19.8742690086
# End of epoch 14: err(train)=1.32 acc(train)=0.53
#                  err(valid)=1.47 acc(valid)=0.48
# 20.9589898586
# End of epoch 15: err(train)=1.31 acc(train)=0.53
#                  err(valid)=1.55 acc(valid)=0.46
# 21.8616640568
# End of epoch 16: err(train)=1.29 acc(train)=0.54
#                  err(valid)=1.50 acc(valid)=0.47
# 23.2846939564
# End of epoch 17: err(train)=1.28 acc(train)=0.54
#                  err(valid)=1.51 acc(valid)=0.48
# 19.1068170071
# End of epoch 18: err(train)=1.26 acc(train)=0.55
#                  err(valid)=1.48 acc(valid)=0.49
# 19.0172748566
# End of epoch 19: err(train)=1.25 acc(train)=0.55
#                  err(valid)=1.56 acc(valid)=0.47
# 19.354580164
# End of epoch 20: err(train)=1.24 acc(train)=0.56
#                  err(valid)=1.48 acc(valid)=0.49
# 19.0827200413
# End of epoch 21: err(train)=1.23 acc(train)=0.56
#                  err(valid)=1.53 acc(valid)=0.48
# 24.1426818371
# End of epoch 22: err(train)=1.22 acc(train)=0.56
#                  err(valid)=1.51 acc(valid)=0.49
# 21.422244072
# End of epoch 23: err(train)=1.20 acc(train)=0.57
#                  err(valid)=1.52 acc(valid)=0.49
# 23.6521692276
# End of epoch 24: err(train)=1.18 acc(train)=0.57
#                  err(valid)=1.55 acc(valid)=0.48
# 21.0738859177
# End of epoch 25: err(train)=1.18 acc(train)=0.57
#                  err(valid)=1.55 acc(valid)=0.49
# 19.0741429329
# End of epoch 26: err(train)=1.17 acc(train)=0.58
#                  err(valid)=1.52 acc(valid)=0.49
# 19.1144578457
# End of epoch 27: err(train)=1.16 acc(train)=0.59
#                  err(valid)=1.54 acc(valid)=0.49
# 21.6134090424
# End of epoch 28: err(train)=1.14 acc(train)=0.59
#                  err(valid)=1.61 acc(valid)=0.47
# 20.4493160248
# End of epoch 29: err(train)=1.13 acc(train)=0.59
#                  err(valid)=1.61 acc(valid)=0.48
# 19.3039150238
# End of epoch 30: err(train)=1.12 acc(train)=0.60
#                  err(valid)=1.59 acc(valid)=0.48
# 19.4214777946
# End of epoch 31: err(train)=1.12 acc(train)=0.60
#                  err(valid)=1.63 acc(valid)=0.47
# 22.8424761295
# End of epoch 32: err(train)=1.11 acc(train)=0.60
#                  err(valid)=1.63 acc(valid)=0.48
# 22.9288730621
# End of epoch 33: err(train)=1.09 acc(train)=0.61
#                  err(valid)=1.59 acc(valid)=0.49
# 22.4336760044
# End of epoch 34: err(train)=1.08 acc(train)=0.61
#                  err(valid)=1.67 acc(valid)=0.47
# 20.1970169544
# End of epoch 35: err(train)=1.07 acc(train)=0.61
#                  err(valid)=1.64 acc(valid)=0.48
# 19.9652371407
# End of epoch 36: err(train)=1.07 acc(train)=0.62
#                  err(valid)=1.67 acc(valid)=0.47
# 21.1011400223
# End of epoch 37: err(train)=1.06 acc(train)=0.62
#                  err(valid)=1.72 acc(valid)=0.47
# 19.0618360043
# End of epoch 38: err(train)=1.05 acc(train)=0.62
#                  err(valid)=1.71 acc(valid)=0.48
# 21.8522911072
# End of epoch 39: err(train)=1.04 acc(train)=0.63
#                  err(valid)=1.68 acc(valid)=0.49
# 20.331731081
# End of epoch 40: err(train)=1.04 acc(train)=0.63
#                  err(valid)=1.77 acc(valid)=0.47
# 19.5335180759
# End of epoch 41: err(train)=1.02 acc(train)=0.63
#                  err(valid)=1.72 acc(valid)=0.48
# 19.3414719105
# End of epoch 42: err(train)=1.02 acc(train)=0.63
#                  err(valid)=1.77 acc(valid)=0.48
# 21.0680558681
# End of epoch 43: err(train)=1.01 acc(train)=0.64
#                  err(valid)=1.75 acc(valid)=0.48
# 22.1469919682
# End of epoch 44: err(train)=1.00 acc(train)=0.64
#                  err(valid)=1.73 acc(valid)=0.47
# 19.521351099
# End of epoch 45: err(train)=1.00 acc(train)=0.64
#                  err(valid)=1.77 acc(valid)=0.48
# 20.7041239738
# End of epoch 46: err(train)=0.99 acc(train)=0.64
#                  err(valid)=1.78 acc(valid)=0.48
# 19.9355089664
# End of epoch 47: err(train)=0.98 acc(train)=0.65
#                  err(valid)=1.80 acc(valid)=0.48
# 20.6152660847
# End of epoch 48: err(train)=0.98 acc(train)=0.65
#                  err(valid)=1.80 acc(valid)=0.47
# 19.1474099159
# End of epoch 49: err(train)=0.97 acc(train)=0.65
#                  err(valid)=1.84 acc(valid)=0.48
# 19.1849868298
# End of epoch 50: err(train)=0.97 acc(train)=0.65
#                  err(valid)=1.82 acc(valid)=0.48
# 20.9379220009
# ('sum time for epochs', 1028.9405221939087)
# tanh--------------------------------------------------
# End of epoch 01: err(train)=2.00 acc(train)=0.27
#                  err(valid)=1.84 acc(valid)=0.35
# 14.6705470085
# End of epoch 02: err(train)=1.85 acc(train)=0.33
#                  err(valid)=1.84 acc(valid)=0.34
# 15.1576778889
# End of epoch 03: err(train)=1.82 acc(train)=0.34
#                  err(valid)=1.81 acc(valid)=0.34
# 14.117328167
# End of epoch 04: err(train)=1.80 acc(train)=0.35
#                  err(valid)=1.79 acc(valid)=0.34
# 16.0347571373
# End of epoch 05: err(train)=1.78 acc(train)=0.35
#                  err(valid)=1.80 acc(valid)=0.35
# 13.6575341225
# End of epoch 06: err(train)=1.76 acc(train)=0.36
#                  err(valid)=1.79 acc(valid)=0.36
# 13.8672828674
# End of epoch 07: err(train)=1.75 acc(train)=0.37
#                  err(valid)=1.79 acc(valid)=0.36
# 13.7133581638
# End of epoch 08: err(train)=1.75 acc(train)=0.37
#                  err(valid)=1.78 acc(valid)=0.36
# 14.8567829132
# End of epoch 09: err(train)=1.74 acc(train)=0.37
#                  err(valid)=1.76 acc(valid)=0.36
# 15.4216489792
# End of epoch 10: err(train)=1.75 acc(train)=0.37
#                  err(valid)=1.76 acc(valid)=0.37
# 13.561675787
# End of epoch 11: err(train)=1.72 acc(train)=0.38
#                  err(valid)=1.71 acc(valid)=0.38
# 13.5201079845
# End of epoch 12: err(train)=1.71 acc(train)=0.39
#                  err(valid)=1.74 acc(valid)=0.37
# 14.8983020782
# End of epoch 13: err(train)=1.69 acc(train)=0.39
#                  err(valid)=1.73 acc(valid)=0.38
# 15.4251351357
# End of epoch 14: err(train)=1.69 acc(train)=0.39
#                  err(valid)=1.71 acc(valid)=0.39
# 14.0146501064
# End of epoch 15: err(train)=1.67 acc(train)=0.40
#                  err(valid)=1.70 acc(valid)=0.38
# 13.4849669933
# End of epoch 16: err(train)=1.67 acc(train)=0.40
#                  err(valid)=1.74 acc(valid)=0.38
# 13.4912219048
# End of epoch 17: err(train)=1.66 acc(train)=0.40
#                  err(valid)=1.73 acc(valid)=0.38
# 13.5548799038
# End of epoch 18: err(train)=1.66 acc(train)=0.40
#                  err(valid)=1.71 acc(valid)=0.39
# 13.7987139225
# End of epoch 19: err(train)=1.66 acc(train)=0.40
#                  err(valid)=1.68 acc(valid)=0.40
# 13.545263052
# End of epoch 20: err(train)=1.65 acc(train)=0.41
#                  err(valid)=1.67 acc(valid)=0.40
# 13.4915060997
# End of epoch 21: err(train)=1.64 acc(train)=0.41
#                  err(valid)=1.72 acc(valid)=0.38
# 13.6455090046
# End of epoch 22: err(train)=1.64 acc(train)=0.41
#                  err(valid)=1.70 acc(valid)=0.39
# 13.6807539463
# End of epoch 23: err(train)=1.64 acc(train)=0.41
#                  err(valid)=1.69 acc(valid)=0.39
# 13.5968937874
# End of epoch 24: err(train)=1.63 acc(train)=0.41
#                  err(valid)=1.74 acc(valid)=0.38
# 13.6468639374
# End of epoch 25: err(train)=1.64 acc(train)=0.41
#                  err(valid)=1.70 acc(valid)=0.38
# 14.2947409153
# End of epoch 26: err(train)=1.63 acc(train)=0.41
#                  err(valid)=1.69 acc(valid)=0.40
# 13.6258499622
# End of epoch 27: err(train)=1.62 acc(train)=0.42
#                  err(valid)=1.67 acc(valid)=0.39
# 13.5931560993
# End of epoch 28: err(train)=1.62 acc(train)=0.41
#                  err(valid)=1.69 acc(valid)=0.40
# 13.6024990082
# End of epoch 29: err(train)=1.63 acc(train)=0.41
#                  err(valid)=1.66 acc(valid)=0.41
# 13.8575561047
# End of epoch 30: err(train)=1.61 acc(train)=0.42
#                  err(valid)=1.67 acc(valid)=0.41
# 14.2273540497
# End of epoch 31: err(train)=1.61 acc(train)=0.42
#                  err(valid)=1.68 acc(valid)=0.40
# 14.0654969215
# End of epoch 32: err(train)=1.61 acc(train)=0.42
#                  err(valid)=1.71 acc(valid)=0.39
# 14.3000619411
# End of epoch 33: err(train)=1.60 acc(train)=0.42
#                  err(valid)=1.71 acc(valid)=0.39
# 14.4991929531
# End of epoch 34: err(train)=1.61 acc(train)=0.42
#                  err(valid)=1.68 acc(valid)=0.39
# 14.1861541271
# End of epoch 35: err(train)=1.60 acc(train)=0.42
#                  err(valid)=1.65 acc(valid)=0.40
# 14.2759370804
# End of epoch 36: err(train)=1.58 acc(train)=0.43
#                  err(valid)=1.66 acc(valid)=0.41
# 13.8637111187
# End of epoch 37: err(train)=1.58 acc(train)=0.43
#                  err(valid)=1.64 acc(valid)=0.41
# 13.6135220528
# End of epoch 38: err(train)=1.58 acc(train)=0.43
#                  err(valid)=1.69 acc(valid)=0.39
# 14.4550719261
# End of epoch 39: err(train)=1.58 acc(train)=0.43
#                  err(valid)=1.66 acc(valid)=0.41
# 14.3181378841
# End of epoch 40: err(train)=1.58 acc(train)=0.43
#                  err(valid)=1.68 acc(valid)=0.39
# 13.6221327782
# End of epoch 41: err(train)=1.57 acc(train)=0.43
#                  err(valid)=1.68 acc(valid)=0.41
# 14.2863230705
# End of epoch 42: err(train)=1.57 acc(train)=0.44
#                  err(valid)=1.63 acc(valid)=0.42
# 13.9377980232
# End of epoch 43: err(train)=1.57 acc(train)=0.44
#                  err(valid)=1.65 acc(valid)=0.41
# 14.2331321239
# End of epoch 44: err(train)=1.55 acc(train)=0.44
#                  err(valid)=1.63 acc(valid)=0.42
# 13.9733700752
# End of epoch 45: err(train)=1.55 acc(train)=0.44
#                  err(valid)=1.68 acc(valid)=0.41
# 14.1115140915
# End of epoch 46: err(train)=1.55 acc(train)=0.44
#                  err(valid)=1.61 acc(valid)=0.42
# 13.8234181404
# End of epoch 47: err(train)=1.55 acc(train)=0.44
#                  err(valid)=1.61 acc(valid)=0.43
# 14.039290905
# End of epoch 48: err(train)=1.55 acc(train)=0.45
#                  err(valid)=1.64 acc(valid)=0.42
# 13.7821600437
# End of epoch 49: err(train)=1.55 acc(train)=0.44
#                  err(valid)=1.63 acc(valid)=0.42
# 14.121792078
# End of epoch 50: err(train)=1.54 acc(train)=0.45
#                  err(valid)=1.64 acc(valid)=0.41
# 14.0627779961
# ('sum time for epochs', 703.6277658939362)
# elu--------------------------------------------------
# End of epoch 01: err(train)=1.96 acc(train)=0.32
#                  err(valid)=1.76 acc(valid)=0.37
# 12.7461500168
# End of epoch 02: err(train)=1.70 acc(train)=0.39
#                  err(valid)=1.77 acc(valid)=0.38
# 13.3406410217
# End of epoch 03: err(train)=1.62 acc(train)=0.42
#                  err(valid)=1.69 acc(valid)=0.40
# 13.3487679958
# End of epoch 04: err(train)=1.56 acc(train)=0.44
#                  err(valid)=1.54 acc(valid)=0.45
# 13.4089958668
# End of epoch 05: err(train)=1.51 acc(train)=0.46
#                  err(valid)=1.54 acc(valid)=0.46
# 13.7498311996
# End of epoch 06: err(train)=1.48 acc(train)=0.47
#                  err(valid)=1.54 acc(valid)=0.45
# 13.6052219868
# End of epoch 07: err(train)=1.45 acc(train)=0.48
#                  err(valid)=1.47 acc(valid)=0.48
# 13.6073610783
# End of epoch 08: err(train)=1.43 acc(train)=0.49
#                  err(valid)=1.49 acc(valid)=0.48
# 13.406400919
# End of epoch 09: err(train)=1.40 acc(train)=0.50
#                  err(valid)=1.44 acc(valid)=0.49
# 13.7199780941
# End of epoch 10: err(train)=1.37 acc(train)=0.51
#                  err(valid)=1.47 acc(valid)=0.48
# 15.9304850101
# End of epoch 11: err(train)=1.35 acc(train)=0.52
#                  err(valid)=1.45 acc(valid)=0.49
# 13.3393228054
# End of epoch 12: err(train)=1.33 acc(train)=0.53
#                  err(valid)=1.47 acc(valid)=0.49
# 13.3182728291
# End of epoch 13: err(train)=1.30 acc(train)=0.53
#                  err(valid)=1.46 acc(valid)=0.49
# 13.4460849762
# End of epoch 14: err(train)=1.28 acc(train)=0.54
#                  err(valid)=1.45 acc(valid)=0.50
# 13.3838899136
# End of epoch 15: err(train)=1.26 acc(train)=0.55
#                  err(valid)=1.46 acc(valid)=0.49
# 13.3821041584
# End of epoch 16: err(train)=1.24 acc(train)=0.55
#                  err(valid)=1.40 acc(valid)=0.52
# 13.2936758995
# End of epoch 17: err(train)=1.23 acc(train)=0.56
#                  err(valid)=1.42 acc(valid)=0.51
# 13.3420979977
# End of epoch 18: err(train)=1.20 acc(train)=0.57
#                  err(valid)=1.44 acc(valid)=0.50
# 13.1030650139
# End of epoch 19: err(train)=1.18 acc(train)=0.57
#                  err(valid)=1.43 acc(valid)=0.52
# 13.3980829716
# End of epoch 20: err(train)=1.17 acc(train)=0.58
#                  err(valid)=1.50 acc(valid)=0.49
# 13.5916640759
# End of epoch 21: err(train)=1.15 acc(train)=0.59
#                  err(valid)=1.48 acc(valid)=0.50
# 13.4871149063
# End of epoch 22: err(train)=1.13 acc(train)=0.60
#                  err(valid)=1.48 acc(valid)=0.50
# 13.335365057
# End of epoch 23: err(train)=1.11 acc(train)=0.60
#                  err(valid)=1.47 acc(valid)=0.52
# 13.388160944
# End of epoch 24: err(train)=1.10 acc(train)=0.61
#                  err(valid)=1.48 acc(valid)=0.51
# 13.4797809124
# End of epoch 25: err(train)=1.08 acc(train)=0.61
#                  err(valid)=1.47 acc(valid)=0.52
# 13.3505358696
# End of epoch 26: err(train)=1.07 acc(train)=0.61
#                  err(valid)=1.46 acc(valid)=0.51
# 13.3546378613
# End of epoch 27: err(train)=1.05 acc(train)=0.62
#                  err(valid)=1.48 acc(valid)=0.52
# 13.4694399834
# End of epoch 28: err(train)=1.04 acc(train)=0.63
#                  err(valid)=1.49 acc(valid)=0.52
# 13.4138131142
# End of epoch 29: err(train)=1.02 acc(train)=0.63
#                  err(valid)=1.55 acc(valid)=0.50
# 13.4078850746
# End of epoch 30: err(train)=1.01 acc(train)=0.64
#                  err(valid)=1.59 acc(valid)=0.50
# 13.3164651394
# End of epoch 31: err(train)=0.99 acc(train)=0.64
#                  err(valid)=1.56 acc(valid)=0.51
# 13.3363749981
# End of epoch 32: err(train)=0.98 acc(train)=0.65
#                  err(valid)=1.55 acc(valid)=0.52
# 13.2938838005
# End of epoch 33: err(train)=0.97 acc(train)=0.65
#                  err(valid)=1.58 acc(valid)=0.50
# 13.3587429523
# End of epoch 34: err(train)=0.95 acc(train)=0.66
#                  err(valid)=1.59 acc(valid)=0.51
# 13.4757192135
# End of epoch 35: err(train)=0.95 acc(train)=0.66
#                  err(valid)=1.58 acc(valid)=0.51
# 13.4376780987
# End of epoch 36: err(train)=0.93 acc(train)=0.66
#                  err(valid)=1.65 acc(valid)=0.51
# 13.3392920494
# End of epoch 37: err(train)=0.92 acc(train)=0.67
#                  err(valid)=1.65 acc(valid)=0.51
# 13.3070640564
# End of epoch 38: err(train)=0.91 acc(train)=0.67
#                  err(valid)=1.64 acc(valid)=0.51
# 13.309043169
# End of epoch 39: err(train)=0.90 acc(train)=0.68
#                  err(valid)=1.69 acc(valid)=0.51
# 13.3759281635
# End of epoch 40: err(train)=0.89 acc(train)=0.68
#                  err(valid)=1.68 acc(valid)=0.51
# 13.2854969501
# End of epoch 41: err(train)=0.87 acc(train)=0.69
#                  err(valid)=1.69 acc(valid)=0.52
# 13.2584149837
# End of epoch 42: err(train)=0.87 acc(train)=0.69
#                  err(valid)=1.87 acc(valid)=0.50
# 13.2622621059
# End of epoch 43: err(train)=0.85 acc(train)=0.69
#                  err(valid)=1.75 acc(valid)=0.51
# 13.3354139328
# End of epoch 44: err(train)=0.84 acc(train)=0.70
#                  err(valid)=1.75 acc(valid)=0.51
# 13.1753599644
# End of epoch 45: err(train)=0.84 acc(train)=0.70
#                  err(valid)=1.80 acc(valid)=0.50
# 13.2044909
# End of epoch 46: err(train)=0.82 acc(train)=0.70
#                  err(valid)=1.89 acc(valid)=0.51
# 13.2631680965
# End of epoch 47: err(train)=0.82 acc(train)=0.70
#                  err(valid)=1.84 acc(valid)=0.51
# 13.3840560913
# End of epoch 48: err(train)=0.79 acc(train)=0.71
#                  err(valid)=1.89 acc(valid)=0.49
# 13.2343599796
# End of epoch 49: err(train)=0.79 acc(train)=0.71
#                  err(valid)=1.89 acc(valid)=0.50
# 13.2189819813
# End of epoch 50: err(train)=0.78 acc(train)=0.72
#                  err(valid)=1.91 acc(valid)=0.50
# 13.4015829563
# ('sum time for epochs', 670.7245271205902)

# %%
#
activations = [tf.nn.sigmoid,tf.nn.relu,tf.nn.tanh,tf.nn.elu]
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in range(loop):
    ax_1.plot(running_error_[k], label=activations[k].func_name)
ax_1.legend(bbox_to_anchor=(1.25, 0.5))
ax_1.set_xlabel('Epoch number')

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)

for k in range(loop):
    ax_2.plot(running_accuracy_[k], label=activations[k].func_name)
ax_2.legend(bbox_to_anchor=(1.25, 0.5))
ax_2.set_xlabel('Epoch number')

fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in range(loop):
    ax_3.plot(valid_error_[k], label=activations[k].func_name)
    
ax_3.legend(bbox_to_anchor=(1.25, 0.5))
ax_3.set_xlabel('Epoch number')

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in range(loop):
    ax_4.plot(valid_accuracy_[k], label=activations[k].func_name)
    
# ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.legend(bbox_to_anchor=(1.25, 0.5))

fig_1.suptitle("training_errE2.1-2hid-500")
fig_1.savefig("training_errE2.1-2hid-500.png")
fig_2.suptitle("training_accE2.1-2hid-500")
fig_2.savefig("training_accE2.1-2hid-500.png")
fig_3.suptitle("valid_errE2.1-2hid-500")
fig_3.savefig("valid_errE2.1-2hid-500.png")
fig_4.suptitle("valid_accE2.1-2hid-500")
fig_4.savefig("valid_accE2.1-2hid-500.png")

plt.show()

# %% [markdown]
# ### CIFAR-100

# %%
train_data = CIFAR100DataProvider('train', batch_size=50)
valid_data = CIFAR100DataProvider('valid', batch_size=50)

# %%
tf.reset_default_graph()

inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
num_hidden = 200

with tf.name_scope('fc-layer-1'):
    hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
with tf.name_scope('output-layer'):
    outputs = fully_connected_layer(hidden_1, num_hidden, train_data.num_classes, tf.identity)

with tf.name_scope('error'):
    error = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(outputs, targets))
with tf.name_scope('accuracy'):
    accuracy = tf.reduce_mean(tf.cast(
            tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
            tf.float32))

with tf.name_scope('train'):
    train_step = tf.train.AdamOptimizer().minimize(error)
    
init = tf.global_variables_initializer()

# %%
sess = tf.Session()
sess.run(init)
for e in range(10):
    running_error = 0.
    running_accuracy = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_accuracy += batch_acc
    running_error /= train_data.num_batches
    running_accuracy /= train_data.num_batches
    print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f}'
          .format(e + 1, running_error, running_accuracy))
    if (e + 1) % 5 == 0:
        valid_error = 0.
        valid_accuracy = 0.
        for input_batch, target_batch in valid_data:
            batch_error, batch_acc = sess.run(
                [error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch})
            valid_error += batch_error
            valid_accuracy += batch_acc
        valid_error /= valid_data.num_batches
        valid_accuracy /= valid_data.num_batches
        print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
               .format(valid_error, valid_accuracy))

# %% [markdown]
# ## Predicting test data classes and creating a Kaggle submission file
#
# An optional [Kaggle in Class](https://inclass.kaggle.com/c/ml2016-7-cifar-100) competition (see email for invite link, you will need to sign-up with a `ed.ac.uk` email address to be able to enter) is being run on the CIFAR-100 (fine-grained) classification task. The scores for the competition are calculated by calculating the proportion of classes correctly predicted on the test set inputs (for which no class labels are provided). Half of the 10000 test inputs are used to calculate a public leaderboard score which will be visible while the competition is in progress and the other half are used to compute the private leaderboard score which will only be unveiled at the end of the competition. Each entrant can make up to two submissions of predictions each day during the competition.
#
# The code and helper function below illustrate how to use the predicted outputs of the TensorFlow network model we just trained to create a submission file which can be uploaded to Kaggle. The required format of the submission file is a `.csv` (Comma Separated Variable) file with two columns: the first is the integer index of the test input in the array in the provided data file (i.e. first row 0, second row 1 and so on) and the second column the corresponding predicted class label as an integer between 0 and 99 inclusive. The predictions must be preceded by a header line as in the following example
#
# ```
# Id,Class
# 0,81
# 1,35
# 2,12
# ...
# ```
#
# Integer class label predictions can be computed from the class probability outputs of the model by performing an `argmax` operation along the last dimension.

# %%
test_inputs = np.load(os.path.join(os.environ['MLP_DATA_DIR'], 'cifar-100-test-inputs.npz'))['inputs']
test_predictions = sess.run(tf.nn.softmax(outputs), feed_dict={inputs: test_inputs})

# %%
def create_kaggle_submission_file(predictions, output_file, overwrite=False):
    if predictions.shape != (10000, 100):
        raise ValueError('predictions should be an array of shape (10000, 25).')
    if not (np.all(predictions >= 0.) and 
            np.all(predictions <= 1.)):
        raise ValueError('predictions should be an array of probabilities in [0, 1].')
    if not np.allclose(predictions.sum(-1), 1):
        raise ValueError('predictions rows should sum to one.')
    if os.path.exists(output_file) and not overwrite:
        raise ValueError('File already exists at {0}'.format(output_file))
    pred_classes = predictions.argmax(-1)
    ids = np.arange(pred_classes.shape[0])
    np.savetxt(output_file, np.column_stack([ids, pred_classes]), fmt='%d',
               delimiter=',', header='Id,Class', comments='')

# %%
create_kaggle_submission_file(test_predictions, 'cifar-100-example-network-submission.csv', True)

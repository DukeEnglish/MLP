# %% [markdown]
# ## Example two-layer classifier models
#
# Below example code is given for creating instances of the CIFAR-10 and CIFAR-100 data provider objects and using them to train simple two-layer feedforward network models with rectified linear activations in TensorFlow. You may wish to use this code as a starting point for your own experiments.

# %%
import os
import tensorflow as tf
import numpy as np
import time
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1,different activation functions : change in defination of fully_connected_layer
# 2,different hidden layer depths: change the construction of net
# 3,different widths,: change num_hidden
# 4,different learning rate schedules,
# 5,different normalisation,
# 6,different regularisation.

# %% [markdown]
# ### CIFAR-10

# %%
train_data = CIFAR10DataProvider('train', batch_size=150)
valid_data = CIFAR10DataProvider('valid', batch_size=150)

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu):
    weights = tf.Variable(
        tf.truncated_normal(
            [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
        'weights')
    biases = tf.Variable(tf.zeros([output_dim]), 'biases')
    outputs = nonlinearity(tf.matmul(inputs, weights) + biases)
    return outputs

# %% [markdown]
# # coursework3-2hid-500-batch=150

# %%
#activations = [tf.nn.relu]
# 2 hidden
activations = [tf.nn.relu,tf.nn.elu]
epoch=50
running_error_=np.zeros((len(activations),epoch))
running_accuracy_ = np.zeros((len(activations),epoch))
valid_error_ = np.zeros((len(activations),epoch))
valid_accuracy_ = np.zeros((len(activations),epoch))
loop=0
## store result in 4 arrays
for activation in activations:
    print(activation.func_name+"--------------------------------------------------")
    inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
    num_hidden = 500

    with tf.name_scope('fc-layer-1'):
        hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden, nonlinearity=activation)
    with tf.name_scope('layer-2'):
        hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        outputs = fully_connected_layer(hidden_2, num_hidden, train_data.num_classes, tf.identity)
    with tf.name_scope('error'):
        error = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(outputs, targets))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(
                tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
                tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)

    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        run_sum_time = time.time()
        for e in range(epoch):
            run_start_time = time.time()
            running_error = 0.
            running_accuracy = 0.
            for input_batch, target_batch in train_data:
                _, batch_error, batch_acc = sess.run(
                    [train_step, error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                running_error += batch_error
                running_accuracy += batch_acc
            running_error /= train_data.num_batches
            running_accuracy /= train_data.num_batches
            print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f}'
                  .format(e + 1, running_error, running_accuracy))
            running_error_[loop][e]=running_error
            running_accuracy_[loop][e]=running_accuracy
            ##if (e + 1) % 5 == 0:
            valid_error = 0.
            valid_accuracy = 0.
            for input_batch, target_batch in valid_data:
                batch_error, batch_acc = sess.run(
                    [error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                valid_error += batch_error
                valid_accuracy += batch_acc
            valid_error /= valid_data.num_batches
            valid_accuracy /= valid_data.num_batches
            print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
                    .format(valid_error, valid_accuracy))
            valid_error_[loop][e]=valid_error
            valid_accuracy_[loop][e]=valid_accuracy
            run_time = time.time() - run_start_time
            print run_time
        time_epochs=time.time()-run_sum_time
        print("sum time for epochs", time_epochs)
    loop+=1
# Out:
# relu--------------------------------------------------
# End of epoch 01: err(train)=2.00 acc(train)=0.30
#                  err(valid)=1.79 acc(valid)=0.36
# 14.4603300095
# End of epoch 02: err(train)=1.70 acc(train)=0.39
#                  err(valid)=1.69 acc(valid)=0.39
# 14.1133050919
# End of epoch 03: err(train)=1.62 acc(train)=0.42
#                  err(valid)=1.60 acc(valid)=0.43
# 19.1956129074
# End of epoch 04: err(train)=1.57 acc(train)=0.44
#                  err(valid)=1.57 acc(valid)=0.44
# 19.854902029
# End of epoch 05: err(train)=1.52 acc(train)=0.46
#                  err(valid)=1.55 acc(valid)=0.45
# 18.3966581821
# End of epoch 06: err(train)=1.48 acc(train)=0.47
#                  err(valid)=1.51 acc(valid)=0.47
# 18.4403369427
# End of epoch 07: err(train)=1.44 acc(train)=0.49
#                  err(valid)=1.51 acc(valid)=0.47
# 18.4258389473
# End of epoch 08: err(train)=1.42 acc(train)=0.49
#                  err(valid)=1.53 acc(valid)=0.46
# 18.4563910961
# End of epoch 09: err(train)=1.40 acc(train)=0.50
#                  err(valid)=1.47 acc(valid)=0.48
# 18.4225699902
# End of epoch 10: err(train)=1.37 acc(train)=0.51
#                  err(valid)=1.50 acc(valid)=0.48
# 18.5582020283
# End of epoch 11: err(train)=1.35 acc(train)=0.52
#                  err(valid)=1.45 acc(valid)=0.49
# 18.4735629559
# End of epoch 12: err(train)=1.32 acc(train)=0.53
#                  err(valid)=1.46 acc(valid)=0.49
# 18.6672198772
# End of epoch 13: err(train)=1.30 acc(train)=0.54
#                  err(valid)=1.44 acc(valid)=0.49
# 18.5576000214
# End of epoch 14: err(train)=1.28 acc(train)=0.54
#                  err(valid)=1.48 acc(valid)=0.48
# 18.2752220631
# End of epoch 15: err(train)=1.25 acc(train)=0.55
#                  err(valid)=1.42 acc(valid)=0.51
# 21.4822180271
# End of epoch 16: err(train)=1.23 acc(train)=0.56
#                  err(valid)=1.41 acc(valid)=0.51
# 19.0558018684
# End of epoch 17: err(train)=1.21 acc(train)=0.57
#                  err(valid)=1.45 acc(valid)=0.50
# 18.4949231148
# End of epoch 18: err(train)=1.19 acc(train)=0.58
#                  err(valid)=1.43 acc(valid)=0.51
# 18.5065591335
# End of epoch 19: err(train)=1.17 acc(train)=0.58
#                  err(valid)=1.48 acc(valid)=0.50
# 18.5163710117
# End of epoch 20: err(train)=1.16 acc(train)=0.58
#                  err(valid)=1.43 acc(valid)=0.51
# 18.5949780941
# End of epoch 21: err(train)=1.13 acc(train)=0.60
#                  err(valid)=1.43 acc(valid)=0.51
# 18.2650020123
# End of epoch 22: err(train)=1.12 acc(train)=0.60
#                  err(valid)=1.44 acc(valid)=0.51
# 18.5262010098
# End of epoch 23: err(train)=1.09 acc(train)=0.61
#                  err(valid)=1.46 acc(valid)=0.50
# 18.6908409595
# End of epoch 24: err(train)=1.08 acc(train)=0.61
#                  err(valid)=1.46 acc(valid)=0.51
# 18.9393529892
# End of epoch 25: err(train)=1.06 acc(train)=0.62
#                  err(valid)=1.48 acc(valid)=0.50
# 18.4356291294
# End of epoch 26: err(train)=1.05 acc(train)=0.62
#                  err(valid)=1.50 acc(valid)=0.50
# 18.4048500061
# End of epoch 27: err(train)=1.03 acc(train)=0.63
#                  err(valid)=1.47 acc(valid)=0.51
# 18.2553651333
# End of epoch 28: err(train)=1.01 acc(train)=0.64
#                  err(valid)=1.50 acc(valid)=0.50
# 18.4784450531
# End of epoch 29: err(train)=1.00 acc(train)=0.64
#                  err(valid)=1.49 acc(valid)=0.52
# 18.6092238426
# End of epoch 30: err(train)=0.98 acc(train)=0.65
#                  err(valid)=1.53 acc(valid)=0.51
# 18.3114800453
# End of epoch 31: err(train)=0.96 acc(train)=0.66
#                  err(valid)=1.53 acc(valid)=0.51
# 18.3143250942
# End of epoch 32: err(train)=0.95 acc(train)=0.66
#                  err(valid)=1.53 acc(valid)=0.51
# 18.7489070892
# End of epoch 33: err(train)=0.93 acc(train)=0.67
#                  err(valid)=1.52 acc(valid)=0.52
# 18.2590579987
# End of epoch 34: err(train)=0.92 acc(train)=0.67
#                  err(valid)=1.57 acc(valid)=0.51
# 18.3723609447
# End of epoch 35: err(train)=0.90 acc(train)=0.68
#                  err(valid)=1.57 acc(valid)=0.51
# 18.4023580551
# End of epoch 36: err(train)=0.89 acc(train)=0.68
#                  err(valid)=1.58 acc(valid)=0.51
# 18.127918005
# End of epoch 37: err(train)=0.87 acc(train)=0.69
#                  err(valid)=1.60 acc(valid)=0.50
# 18.747838974
# End of epoch 38: err(train)=0.87 acc(train)=0.69
#                  err(valid)=1.62 acc(valid)=0.49
# 18.5208189487
# End of epoch 39: err(train)=0.84 acc(train)=0.70
#                  err(valid)=1.63 acc(valid)=0.50
# 18.224750042
# End of epoch 40: err(train)=0.83 acc(train)=0.70
#                  err(valid)=1.61 acc(valid)=0.51
# 18.2404839993
# End of epoch 41: err(train)=0.83 acc(train)=0.70
#                  err(valid)=1.66 acc(valid)=0.50
# 18.3218920231
# End of epoch 42: err(train)=0.81 acc(train)=0.71
#                  err(valid)=1.66 acc(valid)=0.50
# 18.4596741199
# End of epoch 43: err(train)=0.79 acc(train)=0.72
#                  err(valid)=1.71 acc(valid)=0.50
# 18.2019560337
# End of epoch 44: err(train)=0.79 acc(train)=0.72
#                  err(valid)=1.72 acc(valid)=0.50
# 18.196283102
# End of epoch 45: err(train)=0.77 acc(train)=0.72
#                  err(valid)=1.71 acc(valid)=0.51
# 18.2365789413
# End of epoch 46: err(train)=0.77 acc(train)=0.72
#                  err(valid)=1.71 acc(valid)=0.51
# 18.3321568966
# End of epoch 47: err(train)=0.75 acc(train)=0.73
#                  err(valid)=1.76 acc(valid)=0.50
# 18.2098309994
# End of epoch 48: err(train)=0.73 acc(train)=0.74
#                  err(valid)=1.76 acc(valid)=0.50
# 18.1446959972
# End of epoch 49: err(train)=0.73 acc(train)=0.74
#                  err(valid)=1.79 acc(valid)=0.50
# 18.2605741024
# End of epoch 50: err(train)=0.72 acc(train)=0.74
#                  err(valid)=1.77 acc(valid)=0.51
# 18.3895921707
# ('sum time for epochs', 918.5783050060272)
# elu--------------------------------------------------
# End of epoch 01: err(train)=2.08 acc(train)=0.30
#                  err(valid)=1.77 acc(valid)=0.38
# 13.9213089943
# End of epoch 02: err(train)=1.73 acc(train)=0.38
#                  err(valid)=1.70 acc(valid)=0.38
# 14.0132160187
# End of epoch 03: err(train)=1.65 acc(train)=0.41
#                  err(valid)=1.61 acc(valid)=0.43
# 14.4133739471
# End of epoch 04: err(train)=1.57 acc(train)=0.44
#                  err(valid)=1.61 acc(valid)=0.43
# 14.3271529675
# End of epoch 05: err(train)=1.53 acc(train)=0.45
#                  err(valid)=1.55 acc(valid)=0.45
# 14.510406971
# End of epoch 06: err(train)=1.50 acc(train)=0.47
#                  err(valid)=1.52 acc(valid)=0.46
# 14.3192579746
# End of epoch 07: err(train)=1.46 acc(train)=0.48
#                  err(valid)=1.52 acc(valid)=0.46
# 14.328127861
# End of epoch 08: err(train)=1.42 acc(train)=0.49
#                  err(valid)=1.49 acc(valid)=0.47
# 14.660367012
# End of epoch 09: err(train)=1.39 acc(train)=0.50
#                  err(valid)=1.48 acc(valid)=0.48
# 14.4497458935
# End of epoch 10: err(train)=1.36 acc(train)=0.52
#                  err(valid)=1.49 acc(valid)=0.47
# 14.5633831024
# End of epoch 11: err(train)=1.35 acc(train)=0.52
#                  err(valid)=1.55 acc(valid)=0.45
# 14.5183808804
# End of epoch 12: err(train)=1.32 acc(train)=0.53
#                  err(valid)=1.47 acc(valid)=0.48
# 14.8884608746
# End of epoch 13: err(train)=1.30 acc(train)=0.54
#                  err(valid)=1.43 acc(valid)=0.50
# 15.9340798855
# End of epoch 14: err(train)=1.27 acc(train)=0.54
#                  err(valid)=1.47 acc(valid)=0.49
# 14.4955489635
# End of epoch 15: err(train)=1.26 acc(train)=0.55
#                  err(valid)=1.41 acc(valid)=0.50
# 15.0396850109
# End of epoch 16: err(train)=1.24 acc(train)=0.56
#                  err(valid)=1.41 acc(valid)=0.51
# 16.2359158993
# End of epoch 17: err(train)=1.21 acc(train)=0.57
#                  err(valid)=1.41 acc(valid)=0.51
# 16.4526600838
# End of epoch 18: err(train)=1.18 acc(train)=0.58
#                  err(valid)=1.44 acc(valid)=0.51
# 14.5944449902
# End of epoch 19: err(train)=1.16 acc(train)=0.58
#                  err(valid)=1.43 acc(valid)=0.51
# 14.9380469322
# End of epoch 20: err(train)=1.14 acc(train)=0.59
#                  err(valid)=1.42 acc(valid)=0.51
# 15.9829399586
# End of epoch 21: err(train)=1.12 acc(train)=0.60
#                  err(valid)=1.44 acc(valid)=0.51
# 15.0892100334
# End of epoch 22: err(train)=1.11 acc(train)=0.60
#                  err(valid)=1.39 acc(valid)=0.52
# 14.398348093
# End of epoch 23: err(train)=1.08 acc(train)=0.61
#                  err(valid)=1.42 acc(valid)=0.52
# 14.4286971092
# End of epoch 24: err(train)=1.06 acc(train)=0.62
#                  err(valid)=1.45 acc(valid)=0.52
# 15.4109191895
# End of epoch 25: err(train)=1.04 acc(train)=0.63
#                  err(valid)=1.44 acc(valid)=0.52
# 15.5750589371
# End of epoch 26: err(train)=1.02 acc(train)=0.63
#                  err(valid)=1.44 acc(valid)=0.51
# 16.8256192207
# End of epoch 27: err(train)=0.99 acc(train)=0.64
#                  err(valid)=1.44 acc(valid)=0.52
# 15.3638789654
# End of epoch 28: err(train)=0.97 acc(train)=0.65
#                  err(valid)=1.45 acc(valid)=0.53
# 14.2629590034
# End of epoch 29: err(train)=0.95 acc(train)=0.66
#                  err(valid)=1.51 acc(valid)=0.51
# 14.5636119843
# End of epoch 30: err(train)=0.93 acc(train)=0.67
#                  err(valid)=1.47 acc(valid)=0.52
# 16.4012629986
# End of epoch 31: err(train)=0.92 acc(train)=0.67
#                  err(valid)=1.56 acc(valid)=0.52
# 15.4065821171
# End of epoch 32: err(train)=0.90 acc(train)=0.68
#                  err(valid)=1.54 acc(valid)=0.51
# 14.2003400326
# End of epoch 33: err(train)=0.88 acc(train)=0.68
#                  err(valid)=1.53 acc(valid)=0.52
# 15.0805580616
# End of epoch 34: err(train)=0.85 acc(train)=0.70
#                  err(valid)=1.55 acc(valid)=0.52
# 14.3906760216
# End of epoch 35: err(train)=0.84 acc(train)=0.70
#                  err(valid)=1.61 acc(valid)=0.52
# 14.7624089718
# End of epoch 36: err(train)=0.81 acc(train)=0.71
#                  err(valid)=1.64 acc(valid)=0.51
# 15.7771959305
# End of epoch 37: err(train)=0.80 acc(train)=0.71
#                  err(valid)=1.70 acc(valid)=0.51
# 17.5223791599
# End of epoch 38: err(train)=0.79 acc(train)=0.72
#                  err(valid)=1.64 acc(valid)=0.52
# 15.1264500618
# End of epoch 39: err(train)=0.76 acc(train)=0.73
#                  err(valid)=1.68 acc(valid)=0.53
# 14.4113810062
# End of epoch 40: err(train)=0.74 acc(train)=0.73
#                  err(valid)=1.74 acc(valid)=0.53
# 14.2872378826
# End of epoch 41: err(train)=0.73 acc(train)=0.74
#                  err(valid)=1.73 acc(valid)=0.52
# 14.7581300735
# End of epoch 42: err(train)=0.70 acc(train)=0.75
#                  err(valid)=1.75 acc(valid)=0.52
# 15.3278610706
# End of epoch 43: err(train)=0.69 acc(train)=0.75
#                  err(valid)=1.73 acc(valid)=0.52
# 15.2136881351
# End of epoch 44: err(train)=0.68 acc(train)=0.76
#                  err(valid)=1.81 acc(valid)=0.52
# 14.2792098522
# End of epoch 45: err(train)=0.66 acc(train)=0.76
#                  err(valid)=1.85 acc(valid)=0.52
# 15.7914509773
# End of epoch 46: err(train)=0.64 acc(train)=0.77
#                  err(valid)=1.88 acc(valid)=0.51
# 15.8653080463
# End of epoch 47: err(train)=0.64 acc(train)=0.77
#                  err(valid)=1.93 acc(valid)=0.51
# 14.2085618973
# End of epoch 48: err(train)=0.62 acc(train)=0.77
#                  err(valid)=1.92 acc(valid)=0.53
# 15.2124252319
# End of epoch 49: err(train)=0.60 acc(train)=0.78
#                  err(valid)=1.96 acc(valid)=0.51
# 14.9410660267
# End of epoch 50: err(train)=0.59 acc(train)=0.79
#                  err(valid)=1.98 acc(valid)=0.52
# 14.4179291725
# ('sum time for epochs', 749.888986825943)

# %%
#
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in range(loop):
    ax_1.plot(running_error_[k], label=activations[k].func_name)
ax_1.legend(bbox_to_anchor=(1.25, 0.5))
ax_1.set_xlabel('Epoch number')

fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)

for k in range(loop):
    ax_2.plot(running_accuracy_[k], label=activations[k].func_name)
ax_2.legend(bbox_to_anchor=(1.25, 0.5))
ax_2.set_xlabel('Epoch number')

fig_3 = plt.figure(figsize=(8, 4))
ax_3 = fig_3.add_subplot(111)
for k in range(loop):
    ax_3.plot(valid_error_[k], label=activations[k].func_name)
    
ax_3.legend(bbox_to_anchor=(1.25, 0.5))
ax_3.set_xlabel('Epoch number')

fig_4 = plt.figure(figsize=(8, 4))
ax_4 = fig_4.add_subplot(111)
for k in range(loop):
    ax_4.plot(valid_accuracy_[k], label=activations[k].func_name)
    
# ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number')
ax_4.legend(bbox_to_anchor=(1.25, 0.5))

fig_1.suptitle("training_errE2.1-2hid-500-b150")
fig_1.savefig("training_errE2.1-2hid-500-b150.png")
fig_2.suptitle("training_accE2.1-2hid-500-b150")
fig_2.savefig("training_accE2.1-2hid-500-b150.png")
fig_3.suptitle("valid_errE2.1-2hid-500-b150")
fig_3.savefig("valid_errE2.1-2hid-500-b150.png")
fig_4.suptitle("valid_accE2.1-2hid-500-b150")
fig_4.savefig("valid_accE2.1-2hid-500-b150.png")

plt.show()

# %% [markdown]
# ### CIFAR-100

# %%
train_data = CIFAR100DataProvider('train', batch_size=50)
valid_data = CIFAR100DataProvider('valid', batch_size=50)

# %%
tf.reset_default_graph()

inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
num_hidden = 200

with tf.name_scope('fc-layer-1'):
    hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
with tf.name_scope('output-layer'):
    outputs = fully_connected_layer(hidden_1, num_hidden, train_data.num_classes, tf.identity)

with tf.name_scope('error'):
    error = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(outputs, targets))
with tf.name_scope('accuracy'):
    accuracy = tf.reduce_mean(tf.cast(
            tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), 
            tf.float32))

with tf.name_scope('train'):
    train_step = tf.train.AdamOptimizer().minimize(error)
    
init = tf.global_variables_initializer()

# %%
sess = tf.Session()
sess.run(init)
for e in range(10):
    running_error = 0.
    running_accuracy = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_accuracy += batch_acc
    running_error /= train_data.num_batches
    running_accuracy /= train_data.num_batches
    print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f}'
          .format(e + 1, running_error, running_accuracy))
    if (e + 1) % 5 == 0:
        valid_error = 0.
        valid_accuracy = 0.
        for input_batch, target_batch in valid_data:
            batch_error, batch_acc = sess.run(
                [error, accuracy], 
                feed_dict={inputs: input_batch, targets: target_batch})
            valid_error += batch_error
            valid_accuracy += batch_acc
        valid_error /= valid_data.num_batches
        valid_accuracy /= valid_data.num_batches
        print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
               .format(valid_error, valid_accuracy))

# %% [markdown]
# ## Predicting test data classes and creating a Kaggle submission file
#
# An optional [Kaggle in Class](https://inclass.kaggle.com/c/ml2016-7-cifar-100) competition (see email for invite link, you will need to sign-up with a `ed.ac.uk` email address to be able to enter) is being run on the CIFAR-100 (fine-grained) classification task. The scores for the competition are calculated by calculating the proportion of classes correctly predicted on the test set inputs (for which no class labels are provided). Half of the 10000 test inputs are used to calculate a public leaderboard score which will be visible while the competition is in progress and the other half are used to compute the private leaderboard score which will only be unveiled at the end of the competition. Each entrant can make up to two submissions of predictions each day during the competition.
#
# The code and helper function below illustrate how to use the predicted outputs of the TensorFlow network model we just trained to create a submission file which can be uploaded to Kaggle. The required format of the submission file is a `.csv` (Comma Separated Variable) file with two columns: the first is the integer index of the test input in the array in the provided data file (i.e. first row 0, second row 1 and so on) and the second column the corresponding predicted class label as an integer between 0 and 99 inclusive. The predictions must be preceded by a header line as in the following example
#
# ```
# Id,Class
# 0,81
# 1,35
# 2,12
# ...
# ```
#
# Integer class label predictions can be computed from the class probability outputs of the model by performing an `argmax` operation along the last dimension.

# %%
test_inputs = np.load(os.path.join(os.environ['MLP_DATA_DIR'], 'cifar-100-test-inputs.npz'))['inputs']
test_predictions = sess.run(tf.nn.softmax(outputs), feed_dict={inputs: test_inputs})

# %%
def create_kaggle_submission_file(predictions, output_file, overwrite=False):
    if predictions.shape != (10000, 100):
        raise ValueError('predictions should be an array of shape (10000, 25).')
    if not (np.all(predictions >= 0.) and 
            np.all(predictions <= 1.)):
        raise ValueError('predictions should be an array of probabilities in [0, 1].')
    if not np.allclose(predictions.sum(-1), 1):
        raise ValueError('predictions rows should sum to one.')
    if os.path.exists(output_file) and not overwrite:
        raise ValueError('File already exists at {0}'.format(output_file))
    pred_classes = predictions.argmax(-1)
    ids = np.arange(pred_classes.shape[0])
    np.savetxt(output_file, np.column_stack([ids, pred_classes]), fmt='%d',
               delimiter=',', header='Id,Class', comments='')

# %%
create_kaggle_submission_file(test_predictions, 'cifar-100-example-network-submission.csv', True)
